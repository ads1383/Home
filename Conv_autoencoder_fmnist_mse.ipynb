# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.nn.modules import BCELoss

from utilsF import Fmnist, plot_graphs, plot_mnist
import numpy as np

# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_loader, valid_loader, test_loader = Fmnist(valid=10000)
# Out:
#   0%|          | 40960/26421880 [00:00<01:10, 376866.40it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./FMNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 26427392it [00:00, 81406351.24it/s]
# Extracting ./FMNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 32768it [00:00, 595404.27it/s]
#  20%|█▉        | 868352/4422102 [00:00<00:00, 8202132.36it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./FMNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ./FMNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./FMNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 4423680it [00:00, 30859730.59it/s]
# 8192it [00:00, 239139.05it/s]
# Extracting ./FMNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./FMNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting ./FMNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
class FullyConnected(nn.Module):
    def __init__(self, sizes, dropout=False, activation_fn=nn.ReLU()):
        super(FullyConnected, self).__init__()
        layers = []
        
        for i in range(len(sizes) - 2):
            layers.append(nn.Linear(sizes[i], sizes[i+1]))
            layers.append(activation_fn())
            if dropout:
                layers.append(nn.Dropout())

        else: # нам не нужен дропаут и фнкция активации в последнем слое
            layers.append(nn.Linear(sizes[-2], sizes[-1]))
            
        self.model = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.model(x)

# %%
class autoencoder(nn.Module):
    def __init__(self, batchnorm = False, dropout = False, latent_size = 10):
        super(autoencoder, self).__init__()
        layers = []
        layers.append(nn.Conv2d(1, 16, 3, stride=1, padding=1))
        layers.append(nn.ReLU())
        if batchnorm:
            layers.append(nn.BatchNorm2d(16))
        layers.append(nn.MaxPool2d(2, stride=2))                        
        if dropout:
            layers.append(nn.Dropout2d())
        layers.append(nn.Conv2d(16, 32, 3, stride=1, padding=1))
        layers.append(nn.ReLU())
        if batchnorm:
            layers.append(nn.BatchNorm2d(32))
        layers.append(nn.MaxPool2d(2, stride=2, return_indices=False))                        
        if dropout:
            layers.append(nn.Dropout2d())                       
        
        self.encoder = nn.Sequential(*layers)
        
        
        self.fc1 = FullyConnected([32*7*7, latent_size], dropout=True, activation_fn=nn.ReLU())
        self.fc2 = FullyConnected([latent_size, 32*7*7], dropout=True, activation_fn=nn.ReLU())
      
        
        layersd = []
        layersd.append(nn.ConvTranspose2d(32, 16, 3, stride=2, padding=1)) #32 14 14
        layersd.append(nn.ConvTranspose2d(16, 1, 4, stride=2, padding=0))
        layersd.append(nn.Tanh())
        
        self.decoder = nn.Sequential(*layersd)                        
        

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(-1, 32*7*7)
        x = self.fc1(x)
        data_rho = torch.sigmoid(x).mean(0)
        x = self.fc2(x)
        x = torch.relu(x)
        x = x.view(50, 32, 7, 7)
        x = self.decoder(x)
        return x, data_rho

# %%
class Net(nn.Module):
    def __init__(self, latent_size = 10, batchnorm = False, dropout = False,  loss_fn = 
                 F.mse_loss, lr = 1e-4, l2 = 0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.batchnorm = batchnorm
        self.dropout = dropout
        self.ae = autoencoder(batchnorm, dropout, latent_size)
        self.loss_fn = loss_fn
        self._rho_loss = None
        self._loss = None
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
    
 
    def forward(self, x):
        x, self.data_rho = self.ae(x)
        return x

    def rho_loss(self, rho, size_average=True):
        """
        D_KL(P||Q) = sum(p*log(p/q)) = -sum(p*log(q/p)) = -p*log(q/p) - (1-p)log((1-q)/(1-p))
        """
       # dkl = - torch.log(self.data_rho/rho) * rho - torch.log((1-self.data_rho)/(1-rho)) * (1-rho)
        dkl = min(- torch.log(self.data_rho) * rho - torch.log(1-self.data_rho) * (1-rho))
       # print('dkl:', dkl)
        if size_average:
            self._rho_loss = dkl.mean()
        else:
            self._rho_loss = dkl.sum()
        return self._rho_loss
    
    def loss(self, x, target, **kwargs):
        target = target.view(-1, 28*28)
        x = x.view(-1, 28*28)
        self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
models = {'64,TT': Net(64, True, True), '64,TF': Net(64, True, False), '64,FT': Net(64, False, True), '64': Net(64)}
rho = 0.05
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
def train(epoch, models, log=None):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, _) in enumerate(train_loader):
        dataX = (data + 0.5*torch.randn(data.size())).clamp(0,1).to(device)
        data = data.to(device)
        for model in models.values():
            model.optim.zero_grad()
            output = model(dataX)
            rho_loss = model.rho_loss(rho).to(device)
            loss = (model.loss(output, data) + rho_loss).to(device)
            loss.backward()
            model.optim.step()
            
        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._rho_loss))
        print(line + losses)

# %%
avg_lambda = lambda l: 'loss: {:.4f}'.format(l)
rho_lambda = lambda p: 'rho_loss: {:.4f}'.format(p)
line = lambda i, l, p: '{}: '.format(i) + avg_lambda(l) + '\t' + rho_lambda(p)
    
def test(models, loader, log=None):
    test_size = len(loader.sampler)


    test_loss = {k: 0. for k in models}
    rho_loss = {k: 0. for k in models}
    with torch.no_grad():
        for data, _ in loader:
            dataX = (data + 0.5*torch.randn(data.size())).clamp(0,1).to(device)
            data = data.to(device)
            output = {k: m(dataX) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], data,  reduction='sum').item() # sum up batch loss               
                rho_loss[k] += m.rho_loss(rho, size_average=False).item()
               
                
    for k in models:
        test_loss[k] /= (test_size * 784)
        rho_loss[k] /= (test_size * models[k].latent_size)
        if log is not None:
            log[k].append((test_loss[k], rho_loss[k]))
    
    lines = '\n'.join([line(k, test_loss[k], rho_loss[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines        
    print(report)

# %%
for epoch in range(1, 41):
    for model in models.values():
        model = model.to(device)
        model = nn.DataParallel(model)
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model = model.to(device)
        model = nn.DataParallel(model)
        model.eval()
    test(models, valid_loader, test_log)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Losses 64,TT: 1.243729 64,TF: 1.105556 64,FT: 1.180020 64: 1.162763
# Train Epoch: 1 [10000/50000 (20%)]	Losses 64,TT: 0.863299 64,TF: 0.771909 64,FT: 0.962126 64: 0.924305
# Train Epoch: 1 [20000/50000 (40%)]	Losses 64,TT: 0.728738 64,TF: 0.670237 64,FT: 0.745415 64: 0.708178
# Train Epoch: 1 [30000/50000 (60%)]	Losses 64,TT: 0.800466 64,TF: 0.733701 64,FT: 0.821542 64: 0.757119
# Train Epoch: 1 [40000/50000 (80%)]	Losses 64,TT: 0.720471 64,TF: 0.676392 64,FT: 0.729279 64: 0.690675
# Train Epoch: 1 [50000/50000 (100%)]	Losses 64,TT: 0.603795 64,TF: 0.553898 64,FT: 0.630324 64: 0.569933
# Test set:
# 64,TT: loss: 0.5745	rho_loss: 0.0001
# 64,TF: loss: 0.5472	rho_loss: 0.0001
# 64,FT: loss: 0.5970	rho_loss: 0.0001
# 64: loss: 0.5628	rho_loss: 0.0001
#
# Train Epoch: 2 [0/50000 (0%)]	Losses 64,TT: 0.494670 64,TF: 0.458218 64,FT: 0.516380 64: 0.472161
# Train Epoch: 2 [10000/50000 (20%)]	Losses 64,TT: 0.548223 64,TF: 0.506642 64,FT: 0.577679 64: 0.522611
# Train Epoch: 2 [20000/50000 (40%)]	Losses 64,TT: 0.593061 64,TF: 0.550519 64,FT: 0.609920 64: 0.565713
# Train Epoch: 2 [30000/50000 (60%)]	Losses 64,TT: 0.575231 64,TF: 0.545093 64,FT: 0.587704 64: 0.558490
# Train Epoch: 2 [40000/50000 (80%)]	Losses 64,TT: 0.536343 64,TF: 0.498553 64,FT: 0.542964 64: 0.513360
# Train Epoch: 2 [50000/50000 (100%)]	Losses 64,TT: 0.550334 64,TF: 0.513934 64,FT: 0.571812 64: 0.532491
# Test set:
# 64,TT: loss: 0.5369	rho_loss: 0.0001
# 64,TF: loss: 0.5151	rho_loss: 0.0001
# 64,FT: loss: 0.5557	rho_loss: 0.0001
# 64: loss: 0.5295	rho_loss: 0.0001
#
# Train Epoch: 3 [0/50000 (0%)]	Losses 64,TT: 0.577641 64,TF: 0.540550 64,FT: 0.588017 64: 0.553008
# Train Epoch: 3 [10000/50000 (20%)]	Losses 64,TT: 0.623085 64,TF: 0.589602 64,FT: 0.636172 64: 0.604734
# Train Epoch: 3 [20000/50000 (40%)]	Losses 64,TT: 0.496649 64,TF: 0.463165 64,FT: 0.514125 64: 0.479295
# Train Epoch: 3 [30000/50000 (60%)]	Losses 64,TT: 0.548851 64,TF: 0.518091 64,FT: 0.569336 64: 0.532726
# Train Epoch: 3 [40000/50000 (80%)]	Losses 64,TT: 0.556177 64,TF: 0.521960 64,FT: 0.577852 64: 0.533944
# Train Epoch: 3 [50000/50000 (100%)]	Losses 64,TT: 0.523295 64,TF: 0.498975 64,FT: 0.543689 64: 0.513523
# Test set:
# 64,TT: loss: 0.5195	rho_loss: 0.0001
# 64,TF: loss: 0.5008	rho_loss: 0.0001
# 64,FT: loss: 0.5343	rho_loss: 0.0001
# 64: loss: 0.5147	rho_loss: 0.0001
#
# Train Epoch: 4 [0/50000 (0%)]	Losses 64,TT: 0.426234 64,TF: 0.397371 64,FT: 0.439619 64: 0.406352
# Train Epoch: 4 [10000/50000 (20%)]	Losses 64,TT: 0.538745 64,TF: 0.510803 64,FT: 0.550649 64: 0.523275
# Train Epoch: 4 [20000/50000 (40%)]	Losses 64,TT: 0.496800 64,TF: 0.467930 64,FT: 0.504207 64: 0.482356
# Train Epoch: 4 [30000/50000 (60%)]	Losses 64,TT: 0.548549 64,TF: 0.519998 64,FT: 0.556461 64: 0.532217
# Train Epoch: 4 [40000/50000 (80%)]	Losses 64,TT: 0.439300 64,TF: 0.405592 64,FT: 0.448869 64: 0.420340
# Train Epoch: 4 [50000/50000 (100%)]	Losses 64,TT: 0.456833 64,TF: 0.426684 64,FT: 0.469471 64: 0.440463
# Test set:
# 64,TT: loss: 0.5102	rho_loss: 0.0001
# 64,TF: loss: 0.4932	rho_loss: 0.0001
# 64,FT: loss: 0.5224	rho_loss: 0.0001
# 64: loss: 0.5058	rho_loss: 0.0001
#
# Train Epoch: 5 [0/50000 (0%)]	Losses 64,TT: 0.605628 64,TF: 0.579004 64,FT: 0.624422 64: 0.591983
# Train Epoch: 5 [10000/50000 (20%)]	Losses 64,TT: 0.547326 64,TF: 0.518067 64,FT: 0.558726 64: 0.531930
# Train Epoch: 5 [20000/50000 (40%)]	Losses 64,TT: 0.469576 64,TF: 0.436385 64,FT: 0.474757 64: 0.451818
# Train Epoch: 5 [30000/50000 (60%)]	Losses 64,TT: 0.554360 64,TF: 0.526187 64,FT: 0.567509 64: 0.540808
# Train Epoch: 5 [40000/50000 (80%)]	Losses 64,TT: 0.476623 64,TF: 0.450040 64,FT: 0.489900 64: 0.462773
# Train Epoch: 5 [50000/50000 (100%)]	Losses 64,TT: 0.496295 64,TF: 0.470400 64,FT: 0.512596 64: 0.483342
# Test set:
# 64,TT: loss: 0.5035	rho_loss: 0.0001
# 64,TF: loss: 0.4869	rho_loss: 0.0001
# 64,FT: loss: 0.5155	rho_loss: 0.0001
# 64: loss: 0.5001	rho_loss: 0.0001
#
# Train Epoch: 6 [0/50000 (0%)]	Losses 64,TT: 0.630077 64,TF: 0.601600 64,FT: 0.640335 64: 0.612279
# Train Epoch: 6 [10000/50000 (20%)]	Losses 64,TT: 0.454876 64,TF: 0.433897 64,FT: 0.464381 64: 0.445026
# Train Epoch: 6 [20000/50000 (40%)]	Losses 64,TT: 0.529316 64,TF: 0.504864 64,FT: 0.549145 64: 0.517431
# Train Epoch: 6 [30000/50000 (60%)]	Losses 64,TT: 0.462361 64,TF: 0.439202 64,FT: 0.480171 64: 0.450920
# Train Epoch: 6 [40000/50000 (80%)]	Losses 64,TT: 0.489031 64,TF: 0.463947 64,FT: 0.499871 64: 0.476874
# Train Epoch: 6 [50000/50000 (100%)]	Losses 64,TT: 0.509094 64,TF: 0.478299 64,FT: 0.521193 64: 0.492113
# Test set:
# 64,TT: loss: 0.4986	rho_loss: 0.0001
# 64,TF: loss: 0.4828	rho_loss: 0.0001
# 64,FT: loss: 0.5098	rho_loss: 0.0001
# 64: loss: 0.4956	rho_loss: 0.0001
#
# Train Epoch: 7 [0/50000 (0%)]	Losses 64,TT: 0.510250 64,TF: 0.487429 64,FT: 0.522996 64: 0.497660
# Train Epoch: 7 [10000/50000 (20%)]	Losses 64,TT: 0.622439 64,TF: 0.593451 64,FT: 0.632123 64: 0.605905
# Train Epoch: 7 [20000/50000 (40%)]	Losses 64,TT: 0.500865 64,TF: 0.472884 64,FT: 0.515221 64: 0.488009
# Train Epoch: 7 [30000/50000 (60%)]	Losses 64,TT: 0.542621 64,TF: 0.512672 64,FT: 0.551126 64: 0.526160
# Train Epoch: 7 [40000/50000 (80%)]	Losses 64,TT: 0.622033 64,TF: 0.595561 64,FT: 0.634218 64: 0.611165
# Train Epoch: 7 [50000/50000 (100%)]	Losses 64,TT: 0.442439 64,TF: 0.415814 64,FT: 0.459925 64: 0.429461
# Test set:
# 64,TT: loss: 0.4952	rho_loss: 0.0001
# 64,TF: loss: 0.4799	rho_loss: 0.0001
# 64,FT: loss: 0.5058	rho_loss: 0.0001
# 64: loss: 0.4921	rho_loss: 0.0001
#
# Train Epoch: 8 [0/50000 (0%)]	Losses 64,TT: 0.503573 64,TF: 0.483417 64,FT: 0.518531 64: 0.493977
# Train Epoch: 8 [10000/50000 (20%)]	Losses 64,TT: 0.487445 64,TF: 0.461238 64,FT: 0.497856 64: 0.472507
# Train Epoch: 8 [20000/50000 (40%)]	Losses 64,TT: 0.484851 64,TF: 0.459502 64,FT: 0.495156 64: 0.472281
# Train Epoch: 8 [30000/50000 (60%)]	Losses 64,TT: 0.444646 64,TF: 0.421602 64,FT: 0.462029 64: 0.433246
# Train Epoch: 8 [40000/50000 (80%)]	Losses 64,TT: 0.484584 64,TF: 0.463622 64,FT: 0.498253 64: 0.474190
# Train Epoch: 8 [50000/50000 (100%)]	Losses 64,TT: 0.594477 64,TF: 0.569133 64,FT: 0.602232 64: 0.580722
# Test set:
# 64,TT: loss: 0.4919	rho_loss: 0.0001
# 64,TF: loss: 0.4772	rho_loss: 0.0001
# 64,FT: loss: 0.5026	rho_loss: 0.0001
# 64: loss: 0.4890	rho_loss: 0.0001
#
# Train Epoch: 9 [0/50000 (0%)]	Losses 64,TT: 0.591951 64,TF: 0.564004 64,FT: 0.603837 64: 0.575157
# Train Epoch: 9 [10000/50000 (20%)]	Losses 64,TT: 0.500845 64,TF: 0.477464 64,FT: 0.514462 64: 0.489195
# Train Epoch: 9 [20000/50000 (40%)]	Losses 64,TT: 0.462858 64,TF: 0.429231 64,FT: 0.464689 64: 0.442930
# Train Epoch: 9 [30000/50000 (60%)]	Losses 64,TT: 0.530946 64,TF: 0.508351 64,FT: 0.539397 64: 0.519424
# Train Epoch: 9 [40000/50000 (80%)]	Losses 64,TT: 0.517567 64,TF: 0.497357 64,FT: 0.532790 64: 0.507940
# Train Epoch: 9 [50000/50000 (100%)]	Losses 64,TT: 0.499275 64,TF: 0.476917 64,FT: 0.504063 64: 0.486352
# Test set:
# 64,TT: loss: 0.4896	rho_loss: 0.0001
# 64,TF: loss: 0.4752	rho_loss: 0.0001
# 64,FT: loss: 0.4997	rho_loss: 0.0001
# 64: loss: 0.4865	rho_loss: 0.0001
#
# Train Epoch: 10 [0/50000 (0%)]	Losses 64,TT: 0.520477 64,TF: 0.499744 64,FT: 0.531106 64: 0.510236
# Train Epoch: 10 [10000/50000 (20%)]	Losses 64,TT: 0.482378 64,TF: 0.463241 64,FT: 0.490461 64: 0.473122
# Train Epoch: 10 [20000/50000 (40%)]	Losses 64,TT: 0.510220 64,TF: 0.485606 64,FT: 0.517726 64: 0.496617
# Train Epoch: 10 [30000/50000 (60%)]	Losses 64,TT: 0.507516 64,TF: 0.487689 64,FT: 0.520368 64: 0.497066
# Train Epoch: 10 [40000/50000 (80%)]	Losses 64,TT: 0.480044 64,TF: 0.456246 64,FT: 0.491073 64: 0.466263
# Train Epoch: 10 [50000/50000 (100%)]	Losses 64,TT: 0.480942 64,TF: 0.457266 64,FT: 0.490541 64: 0.468982
# Test set:
# 64,TT: loss: 0.4874	rho_loss: 0.0001
# 64,TF: loss: 0.4735	rho_loss: 0.0001
# 64,FT: loss: 0.4973	rho_loss: 0.0001
# 64: loss: 0.4842	rho_loss: 0.0001
#
# Train Epoch: 11 [0/50000 (0%)]	Losses 64,TT: 0.497686 64,TF: 0.476420 64,FT: 0.512262 64: 0.487330
# Train Epoch: 11 [10000/50000 (20%)]	Losses 64,TT: 0.482714 64,TF: 0.461164 64,FT: 0.493679 64: 0.472851
# Train Epoch: 11 [20000/50000 (40%)]	Losses 64,TT: 0.547332 64,TF: 0.524121 64,FT: 0.553914 64: 0.534159
# Train Epoch: 11 [30000/50000 (60%)]	Losses 64,TT: 0.512500 64,TF: 0.490574 64,FT: 0.520347 64: 0.500055
# Train Epoch: 11 [40000/50000 (80%)]	Losses 64,TT: 0.514773 64,TF: 0.485111 64,FT: 0.525012 64: 0.496731
# Train Epoch: 11 [50000/50000 (100%)]	Losses 64,TT: 0.571756 64,TF: 0.547485 64,FT: 0.581277 64: 0.558059
# Test set:
# 64,TT: loss: 0.4855	rho_loss: 0.0001
# 64,TF: loss: 0.4721	rho_loss: 0.0001
# 64,FT: loss: 0.4953	rho_loss: 0.0001
# 64: loss: 0.4824	rho_loss: 0.0001
#
# Train Epoch: 12 [0/50000 (0%)]	Losses 64,TT: 0.510767 64,TF: 0.493351 64,FT: 0.525498 64: 0.501659
# Train Epoch: 12 [10000/50000 (20%)]	Losses 64,TT: 0.526351 64,TF: 0.503222 64,FT: 0.534348 64: 0.512891
# Train Epoch: 12 [20000/50000 (40%)]	Losses 64,TT: 0.585794 64,TF: 0.561643 64,FT: 0.593859 64: 0.574549
# Train Epoch: 12 [30000/50000 (60%)]	Losses 64,TT: 0.540643 64,TF: 0.519703 64,FT: 0.550549 64: 0.530292
# Train Epoch: 12 [40000/50000 (80%)]	Losses 64,TT: 0.539029 64,TF: 0.514799 64,FT: 0.546406 64: 0.526091
# Train Epoch: 12 [50000/50000 (100%)]	Losses 64,TT: 0.516020 64,TF: 0.494698 64,FT: 0.527547 64: 0.504765
# Test set:
# 64,TT: loss: 0.4838	rho_loss: 0.0001
# 64,TF: loss: 0.4709	rho_loss: 0.0001
# 64,FT: loss: 0.4935	rho_loss: 0.0001
# 64: loss: 0.4805	rho_loss: 0.0001
#
# Train Epoch: 13 [0/50000 (0%)]	Losses 64,TT: 0.547199 64,TF: 0.525672 64,FT: 0.554876 64: 0.534360
# Train Epoch: 13 [10000/50000 (20%)]	Losses 64,TT: 0.485625 64,TF: 0.466638 64,FT: 0.499730 64: 0.475599
# Train Epoch: 13 [20000/50000 (40%)]	Losses 64,TT: 0.501784 64,TF: 0.482851 64,FT: 0.513565 64: 0.492663
# Train Epoch: 13 [30000/50000 (60%)]	Losses 64,TT: 0.407053 64,TF: 0.387415 64,FT: 0.418906 64: 0.394371
# Train Epoch: 13 [40000/50000 (80%)]	Losses 64,TT: 0.502657 64,TF: 0.483228 64,FT: 0.514135 64: 0.491946
# Train Epoch: 13 [50000/50000 (100%)]	Losses 64,TT: 0.483999 64,TF: 0.465856 64,FT: 0.495641 64: 0.474093
# Test set:
# 64,TT: loss: 0.4824	rho_loss: 0.0001
# 64,TF: loss: 0.4697	rho_loss: 0.0001
# 64,FT: loss: 0.4922	rho_loss: 0.0001
# 64: loss: 0.4794	rho_loss: 0.0001
#
# Train Epoch: 14 [0/50000 (0%)]	Losses 64,TT: 0.511894 64,TF: 0.490533 64,FT: 0.520258 64: 0.498543
# Train Epoch: 14 [10000/50000 (20%)]	Losses 64,TT: 0.491737 64,TF: 0.474661 64,FT: 0.505171 64: 0.484274
# Train Epoch: 14 [20000/50000 (40%)]	Losses 64,TT: 0.484168 64,TF: 0.458918 64,FT: 0.500130 64: 0.470501
# Train Epoch: 14 [30000/50000 (60%)]	Losses 64,TT: 0.493036 64,TF: 0.470133 64,FT: 0.501257 64: 0.481423
# Train Epoch: 14 [40000/50000 (80%)]	Losses 64,TT: 0.489411 64,TF: 0.469131 64,FT: 0.497525 64: 0.479180
# Train Epoch: 14 [50000/50000 (100%)]	Losses 64,TT: 0.446766 64,TF: 0.429042 64,FT: 0.458867 64: 0.438321
# Test set:
# 64,TT: loss: 0.4810	rho_loss: 0.0001
# 64,TF: loss: 0.4687	rho_loss: 0.0001
# 64,FT: loss: 0.4907	rho_loss: 0.0001
# 64: loss: 0.4781	rho_loss: 0.0001
#
# Train Epoch: 15 [0/50000 (0%)]	Losses 64,TT: 0.472352 64,TF: 0.455018 64,FT: 0.483851 64: 0.463681
# Train Epoch: 15 [10000/50000 (20%)]	Losses 64,TT: 0.495223 64,TF: 0.474338 64,FT: 0.510186 64: 0.483207
# Train Epoch: 15 [20000/50000 (40%)]	Losses 64,TT: 0.494976 64,TF: 0.473285 64,FT: 0.511834 64: 0.484768
# Train Epoch: 15 [30000/50000 (60%)]	Losses 64,TT: 0.390229 64,TF: 0.371280 64,FT: 0.400834 64: 0.380392
# Train Epoch: 15 [40000/50000 (80%)]	Losses 64,TT: 0.572937 64,TF: 0.552650 64,FT: 0.583152 64: 0.561158
# Train Epoch: 15 [50000/50000 (100%)]	Losses 64,TT: 0.442063 64,TF: 0.424981 64,FT: 0.451011 64: 0.432331
# Test set:
# 64,TT: loss: 0.4799	rho_loss: 0.0001
# 64,TF: loss: 0.4679	rho_loss: 0.0001
# 64,FT: loss: 0.4895	rho_loss: 0.0001
# 64: loss: 0.4770	rho_loss: 0.0001
#
# Train Epoch: 16 [0/50000 (0%)]	Losses 64,TT: 0.497461 64,TF: 0.480944 64,FT: 0.512491 64: 0.488757
# Train Epoch: 16 [10000/50000 (20%)]	Losses 64,TT: 0.393319 64,TF: 0.372361 64,FT: 0.408397 64: 0.382700
# Train Epoch: 16 [20000/50000 (40%)]	Losses 64,TT: 0.461283 64,TF: 0.442821 64,FT: 0.473027 64: 0.451052
# Train Epoch: 16 [30000/50000 (60%)]	Losses 64,TT: 0.424966 64,TF: 0.396828 64,FT: 0.431678 64: 0.408043
# Train Epoch: 16 [40000/50000 (80%)]	Losses 64,TT: 0.551954 64,TF: 0.535203 64,FT: 0.563653 64: 0.542823
# Train Epoch: 16 [50000/50000 (100%)]	Losses 64,TT: 0.443457 64,TF: 0.425640 64,FT: 0.453957 64: 0.433687
# Test set:
# 64,TT: loss: 0.4788	rho_loss: 0.0001
# 64,TF: loss: 0.4669	rho_loss: 0.0001
# 64,FT: loss: 0.4880	rho_loss: 0.0001
# 64: loss: 0.4757	rho_loss: 0.0001
#
# Train Epoch: 17 [0/50000 (0%)]	Losses 64,TT: 0.368802 64,TF: 0.351502 64,FT: 0.378333 64: 0.358285
# Train Epoch: 17 [10000/50000 (20%)]	Losses 64,TT: 0.482993 64,TF: 0.467208 64,FT: 0.492926 64: 0.474849
# Train Epoch: 17 [20000/50000 (40%)]	Losses 64,TT: 0.458413 64,TF: 0.437140 64,FT: 0.471384 64: 0.447632
# Train Epoch: 17 [30000/50000 (60%)]	Losses 64,TT: 0.492276 64,TF: 0.476952 64,FT: 0.507680 64: 0.485786
# Train Epoch: 17 [40000/50000 (80%)]	Losses 64,TT: 0.542753 64,TF: 0.524087 64,FT: 0.554818 64: 0.534415
# Train Epoch: 17 [50000/50000 (100%)]	Losses 64,TT: 0.609343 64,TF: 0.590528 64,FT: 0.620712 64: 0.599274
# Test set:
# 64,TT: loss: 0.4777	rho_loss: 0.0001
# 64,TF: loss: 0.4663	rho_loss: 0.0001
# 64,FT: loss: 0.4871	rho_loss: 0.0001
# 64: loss: 0.4747	rho_loss: 0.0001
#
# Train Epoch: 18 [0/50000 (0%)]	Losses 64,TT: 0.422368 64,TF: 0.403281 64,FT: 0.431827 64: 0.411390
# Train Epoch: 18 [10000/50000 (20%)]	Losses 64,TT: 0.517466 64,TF: 0.497463 64,FT: 0.527801 64: 0.505304
# Train Epoch: 18 [20000/50000 (40%)]	Losses 64,TT: 0.508215 64,TF: 0.486377 64,FT: 0.519285 64: 0.498156
# Train Epoch: 18 [30000/50000 (60%)]	Losses 64,TT: 0.518930 64,TF: 0.499633 64,FT: 0.532377 64: 0.509355
# Train Epoch: 18 [40000/50000 (80%)]	Losses 64,TT: 0.481482 64,TF: 0.463570 64,FT: 0.496458 64: 0.472412
# Train Epoch: 18 [50000/50000 (100%)]	Losses 64,TT: 0.468685 64,TF: 0.450273 64,FT: 0.479254 64: 0.459326
# Test set:
# 64,TT: loss: 0.4769	rho_loss: 0.0001
# 64,TF: loss: 0.4656	rho_loss: 0.0001
# 64,FT: loss: 0.4863	rho_loss: 0.0001
# 64: loss: 0.4740	rho_loss: 0.0001
#
# Train Epoch: 19 [0/50000 (0%)]	Losses 64,TT: 0.430418 64,TF: 0.412945 64,FT: 0.439567 64: 0.422289
# Train Epoch: 19 [10000/50000 (20%)]	Losses 64,TT: 0.480491 64,TF: 0.461605 64,FT: 0.487238 64: 0.468559
# Train Epoch: 19 [20000/50000 (40%)]	Losses 64,TT: 0.509704 64,TF: 0.493427 64,FT: 0.519595 64: 0.500536
# Train Epoch: 19 [30000/50000 (60%)]	Losses 64,TT: 0.523261 64,TF: 0.504302 64,FT: 0.532216 64: 0.511533
# Train Epoch: 19 [40000/50000 (80%)]	Losses 64,TT: 0.507170 64,TF: 0.487491 64,FT: 0.518072 64: 0.497049
# Train Epoch: 19 [50000/50000 (100%)]	Losses 64,TT: 0.559577 64,TF: 0.539393 64,FT: 0.571591 64: 0.546885
# Test set:
# 64,TT: loss: 0.4762	rho_loss: 0.0001
# 64,TF: loss: 0.4650	rho_loss: 0.0001
# 64,FT: loss: 0.4853	rho_loss: 0.0001
# 64: loss: 0.4730	rho_loss: 0.0001
#
# Train Epoch: 20 [0/50000 (0%)]	Losses 64,TT: 0.451856 64,TF: 0.435782 64,FT: 0.461201 64: 0.442827
# Train Epoch: 20 [10000/50000 (20%)]	Losses 64,TT: 0.391456 64,TF: 0.372312 64,FT: 0.403830 64: 0.381736
# Train Epoch: 20 [20000/50000 (40%)]	Losses 64,TT: 0.462105 64,TF: 0.444016 64,FT: 0.471016 64: 0.452905
# Train Epoch: 20 [30000/50000 (60%)]	Losses 64,TT: 0.419186 64,TF: 0.397465 64,FT: 0.429746 64: 0.407283
# Train Epoch: 20 [40000/50000 (80%)]	Losses 64,TT: 0.460088 64,TF: 0.440727 64,FT: 0.468075 64: 0.448671
# Train Epoch: 20 [50000/50000 (100%)]	Losses 64,TT: 0.521127 64,TF: 0.503369 64,FT: 0.530440 64: 0.511582
# Test set:
# 64,TT: loss: 0.4755	rho_loss: 0.0001
# 64,TF: loss: 0.4644	rho_loss: 0.0001
# 64,FT: loss: 0.4844	rho_loss: 0.0001
# 64: loss: 0.4724	rho_loss: 0.0001
#
# Train Epoch: 21 [0/50000 (0%)]	Losses 64,TT: 0.499463 64,TF: 0.482358 64,FT: 0.511572 64: 0.491599
# Train Epoch: 21 [10000/50000 (20%)]	Losses 64,TT: 0.592225 64,TF: 0.573183 64,FT: 0.603944 64: 0.582270
# Train Epoch: 21 [20000/50000 (40%)]	Losses 64,TT: 0.531111 64,TF: 0.510829 64,FT: 0.542836 64: 0.518997
# Train Epoch: 21 [30000/50000 (60%)]	Losses 64,TT: 0.488945 64,TF: 0.467323 64,FT: 0.501051 64: 0.474781
# Train Epoch: 21 [40000/50000 (80%)]	Losses 64,TT: 0.467025 64,TF: 0.450211 64,FT: 0.482242 64: 0.458827
# Train Epoch: 21 [50000/50000 (100%)]	Losses 64,TT: 0.491035 64,TF: 0.471991 64,FT: 0.503339 64: 0.478806
# Test set:
# 64,TT: loss: 0.4747	rho_loss: 0.0001
# 64,TF: loss: 0.4638	rho_loss: 0.0001
# 64,FT: loss: 0.4840	rho_loss: 0.0001
# 64: loss: 0.4716	rho_loss: 0.0001
#
# Train Epoch: 22 [0/50000 (0%)]	Losses 64,TT: 0.466780 64,TF: 0.451121 64,FT: 0.478554 64: 0.457372
# Train Epoch: 22 [10000/50000 (20%)]	Losses 64,TT: 0.562682 64,TF: 0.540979 64,FT: 0.573135 64: 0.549496
# Train Epoch: 22 [20000/50000 (40%)]	Losses 64,TT: 0.438830 64,TF: 0.421513 64,FT: 0.447947 64: 0.428657
# Train Epoch: 22 [30000/50000 (60%)]	Losses 64,TT: 0.459399 64,TF: 0.439847 64,FT: 0.472225 64: 0.449367
# Train Epoch: 22 [40000/50000 (80%)]	Losses 64,TT: 0.486316 64,TF: 0.472589 64,FT: 0.499235 64: 0.479199
# Train Epoch: 22 [50000/50000 (100%)]	Losses 64,TT: 0.432271 64,TF: 0.413343 64,FT: 0.444616 64: 0.421821
# Test set:
# 64,TT: loss: 0.4742	rho_loss: 0.0001
# 64,TF: loss: 0.4633	rho_loss: 0.0001
# 64,FT: loss: 0.4830	rho_loss: 0.0001
# 64: loss: 0.4711	rho_loss: 0.0001
#
# Train Epoch: 23 [0/50000 (0%)]	Losses 64,TT: 0.405018 64,TF: 0.384464 64,FT: 0.413704 64: 0.393667
# Train Epoch: 23 [10000/50000 (20%)]	Losses 64,TT: 0.523275 64,TF: 0.506493 64,FT: 0.533616 64: 0.514306
# Train Epoch: 23 [20000/50000 (40%)]	Losses 64,TT: 0.509127 64,TF: 0.491370 64,FT: 0.520410 64: 0.499710
# Train Epoch: 23 [30000/50000 (60%)]	Losses 64,TT: 0.430451 64,TF: 0.413371 64,FT: 0.439144 64: 0.420321
# Train Epoch: 23 [40000/50000 (80%)]	Losses 64,TT: 0.482354 64,TF: 0.466477 64,FT: 0.494588 64: 0.473446
# Train Epoch: 23 [50000/50000 (100%)]	Losses 64,TT: 0.416530 64,TF: 0.398234 64,FT: 0.424511 64: 0.405886
# Test set:
# 64,TT: loss: 0.4736	rho_loss: 0.0001
# 64,TF: loss: 0.4629	rho_loss: 0.0001
# 64,FT: loss: 0.4823	rho_loss: 0.0001
# 64: loss: 0.4704	rho_loss: 0.0001
#
# Train Epoch: 24 [0/50000 (0%)]	Losses 64,TT: 0.428307 64,TF: 0.411441 64,FT: 0.438540 64: 0.418769
# Train Epoch: 24 [10000/50000 (20%)]	Losses 64,TT: 0.533523 64,TF: 0.516454 64,FT: 0.542742 64: 0.522754
# Train Epoch: 24 [20000/50000 (40%)]	Losses 64,TT: 0.535987 64,TF: 0.518722 64,FT: 0.545170 64: 0.526313
# Train Epoch: 24 [30000/50000 (60%)]	Losses 64,TT: 0.420448 64,TF: 0.403269 64,FT: 0.430510 64: 0.411133
# Train Epoch: 24 [40000/50000 (80%)]	Losses 64,TT: 0.410371 64,TF: 0.394912 64,FT: 0.420554 64: 0.400740
# Train Epoch: 24 [50000/50000 (100%)]	Losses 64,TT: 0.439524 64,TF: 0.405795 64,FT: 0.432416 64: 0.412922
# Test set:
# 64,TT: loss: 0.4729	rho_loss: 0.0001
# 64,TF: loss: 0.4625	rho_loss: 0.0001
# 64,FT: loss: 0.4816	rho_loss: 0.0001
# 64: loss: 0.4699	rho_loss: 0.0001
#
# Train Epoch: 25 [0/50000 (0%)]	Losses 64,TT: 0.517557 64,TF: 0.498340 64,FT: 0.528917 64: 0.507966
# Train Epoch: 25 [10000/50000 (20%)]	Losses 64,TT: 0.462795 64,TF: 0.445975 64,FT: 0.475944 64: 0.454442
# Train Epoch: 25 [20000/50000 (40%)]	Losses 64,TT: 0.503667 64,TF: 0.485468 64,FT: 0.514921 64: 0.493852
# Train Epoch: 25 [30000/50000 (60%)]	Losses 64,TT: 0.528447 64,TF: 0.508001 64,FT: 0.537499 64: 0.516131
# Train Epoch: 25 [40000/50000 (80%)]	Losses 64,TT: 0.517512 64,TF: 0.499793 64,FT: 0.527564 64: 0.507644
# Train Epoch: 25 [50000/50000 (100%)]	Losses 64,TT: 0.520113 64,TF: 0.502154 64,FT: 0.531688 64: 0.510624
# Test set:
# 64,TT: loss: 0.4725	rho_loss: 0.0001
# 64,TF: loss: 0.4620	rho_loss: 0.0001
# 64,FT: loss: 0.4810	rho_loss: 0.0001
# 64: loss: 0.4692	rho_loss: 0.0001
#
# Train Epoch: 26 [0/50000 (0%)]	Losses 64,TT: 0.515419 64,TF: 0.498884 64,FT: 0.526632 64: 0.506180
# Train Epoch: 26 [10000/50000 (20%)]	Losses 64,TT: 0.521554 64,TF: 0.504210 64,FT: 0.531149 64: 0.512041
# Train Epoch: 26 [20000/50000 (40%)]	Losses 64,TT: 0.478651 64,TF: 0.463803 64,FT: 0.491410 64: 0.470370
# Train Epoch: 26 [30000/50000 (60%)]	Losses 64,TT: 0.502961 64,TF: 0.486362 64,FT: 0.514152 64: 0.492779
# Train Epoch: 26 [40000/50000 (80%)]	Losses 64,TT: 0.403690 64,TF: 0.386597 64,FT: 0.409672 64: 0.394545
# Train Epoch: 26 [50000/50000 (100%)]	Losses 64,TT: 0.500138 64,TF: 0.485608 64,FT: 0.509984 64: 0.491190
# Test set:
# 64,TT: loss: 0.4719	rho_loss: 0.0001
# 64,TF: loss: 0.4616	rho_loss: 0.0001
# 64,FT: loss: 0.4805	rho_loss: 0.0001
# 64: loss: 0.4686	rho_loss: 0.0001
#
# Train Epoch: 27 [0/50000 (0%)]	Losses 64,TT: 0.523307 64,TF: 0.504940 64,FT: 0.530527 64: 0.513056
# Train Epoch: 27 [10000/50000 (20%)]	Losses 64,TT: 0.531196 64,TF: 0.513456 64,FT: 0.542798 64: 0.522304
# Train Epoch: 27 [20000/50000 (40%)]	Losses 64,TT: 0.527332 64,TF: 0.507835 64,FT: 0.535846 64: 0.515328
# Train Epoch: 27 [30000/50000 (60%)]	Losses 64,TT: 0.418905 64,TF: 0.401573 64,FT: 0.427297 64: 0.409704
# Train Epoch: 27 [40000/50000 (80%)]	Losses 64,TT: 0.554740 64,TF: 0.539057 64,FT: 0.565349 64: 0.545368
# Train Epoch: 27 [50000/50000 (100%)]	Losses 64,TT: 0.464989 64,TF: 0.451728 64,FT: 0.477574 64: 0.458185
# Test set:
# 64,TT: loss: 0.4715	rho_loss: 0.0001
# 64,TF: loss: 0.4613	rho_loss: 0.0001
# 64,FT: loss: 0.4799	rho_loss: 0.0001
# 64: loss: 0.4682	rho_loss: 0.0001
#
# Train Epoch: 28 [0/50000 (0%)]	Losses 64,TT: 0.484518 64,TF: 0.468252 64,FT: 0.496489 64: 0.474495
# Train Epoch: 28 [10000/50000 (20%)]	Losses 64,TT: 0.536514 64,TF: 0.519803 64,FT: 0.547610 64: 0.528335
# Train Epoch: 28 [20000/50000 (40%)]	Losses 64,TT: 0.497597 64,TF: 0.481697 64,FT: 0.507615 64: 0.489390
# Train Epoch: 28 [30000/50000 (60%)]	Losses 64,TT: 0.510406 64,TF: 0.492400 64,FT: 0.522457 64: 0.500045
# Train Epoch: 28 [40000/50000 (80%)]	Losses 64,TT: 0.515688 64,TF: 0.497100 64,FT: 0.522682 64: 0.504140
# Train Epoch: 28 [50000/50000 (100%)]	Losses 64,TT: 0.528456 64,TF: 0.511968 64,FT: 0.541050 64: 0.518998
# Test set:
# 64,TT: loss: 0.4711	rho_loss: 0.0001
# 64,TF: loss: 0.4609	rho_loss: 0.0001
# 64,FT: loss: 0.4794	rho_loss: 0.0001
# 64: loss: 0.4677	rho_loss: 0.0001
#
# Train Epoch: 29 [0/50000 (0%)]	Losses 64,TT: 0.354420 64,TF: 0.333773 64,FT: 0.364418 64: 0.340897
# Train Epoch: 29 [10000/50000 (20%)]	Losses 64,TT: 0.515716 64,TF: 0.498071 64,FT: 0.528779 64: 0.505436
# Train Epoch: 29 [20000/50000 (40%)]	Losses 64,TT: 0.446712 64,TF: 0.429760 64,FT: 0.454995 64: 0.437199
# Train Epoch: 29 [30000/50000 (60%)]	Losses 64,TT: 0.483490 64,TF: 0.465416 64,FT: 0.496313 64: 0.473122
# Train Epoch: 29 [40000/50000 (80%)]	Losses 64,TT: 0.440619 64,TF: 0.424913 64,FT: 0.450430 64: 0.431944
# Train Epoch: 29 [50000/50000 (100%)]	Losses 64,TT: 0.517938 64,TF: 0.501256 64,FT: 0.527120 64: 0.506907
# Test set:
# 64,TT: loss: 0.4707	rho_loss: 0.0001
# 64,TF: loss: 0.4606	rho_loss: 0.0001
# 64,FT: loss: 0.4787	rho_loss: 0.0001
# 64: loss: 0.4673	rho_loss: 0.0001
#
# Train Epoch: 30 [0/50000 (0%)]	Losses 64,TT: 0.571821 64,TF: 0.554692 64,FT: 0.578998 64: 0.560971
# Train Epoch: 30 [10000/50000 (20%)]	Losses 64,TT: 0.451795 64,TF: 0.432589 64,FT: 0.466259 64: 0.440514
# Train Epoch: 30 [20000/50000 (40%)]	Losses 64,TT: 0.525697 64,TF: 0.508504 64,FT: 0.536873 64: 0.516090
# Train Epoch: 30 [30000/50000 (60%)]	Losses 64,TT: 0.468075 64,TF: 0.452205 64,FT: 0.476106 64: 0.458698
# Train Epoch: 30 [40000/50000 (80%)]	Losses 64,TT: 0.484119 64,TF: 0.464553 64,FT: 0.491349 64: 0.470928
# Train Epoch: 30 [50000/50000 (100%)]	Losses 64,TT: 0.470509 64,TF: 0.455630 64,FT: 0.481268 64: 0.461054
# Test set:
# 64,TT: loss: 0.4703	rho_loss: 0.0001
# 64,TF: loss: 0.4603	rho_loss: 0.0001
# 64,FT: loss: 0.4784	rho_loss: 0.0001
# 64: loss: 0.4668	rho_loss: 0.0001
#
# Train Epoch: 31 [0/50000 (0%)]	Losses 64,TT: 0.552289 64,TF: 0.534977 64,FT: 0.561627 64: 0.542073
# Train Epoch: 31 [10000/50000 (20%)]	Losses 64,TT: 0.445025 64,TF: 0.431788 64,FT: 0.455186 64: 0.438303
# Train Epoch: 31 [20000/50000 (40%)]	Losses 64,TT: 0.535355 64,TF: 0.520236 64,FT: 0.545014 64: 0.526931
# Train Epoch: 31 [30000/50000 (60%)]	Losses 64,TT: 0.525173 64,TF: 0.505564 64,FT: 0.533133 64: 0.512405
# Train Epoch: 31 [40000/50000 (80%)]	Losses 64,TT: 0.514088 64,TF: 0.499497 64,FT: 0.526625 64: 0.507596
# Train Epoch: 31 [50000/50000 (100%)]	Losses 64,TT: 0.408741 64,TF: 0.394344 64,FT: 0.415932 64: 0.400453
# Test set:
# 64,TT: loss: 0.4703	rho_loss: 0.0001
# 64,TF: loss: 0.4601	rho_loss: 0.0001
# 64,FT: loss: 0.4780	rho_loss: 0.0001
# 64: loss: 0.4664	rho_loss: 0.0001
#
# Train Epoch: 32 [0/50000 (0%)]	Losses 64,TT: 0.521804 64,TF: 0.505565 64,FT: 0.530951 64: 0.511102
# Train Epoch: 32 [10000/50000 (20%)]	Losses 64,TT: 0.503902 64,TF: 0.482858 64,FT: 0.512041 64: 0.490915
# Train Epoch: 32 [20000/50000 (40%)]	Losses 64,TT: 0.528152 64,TF: 0.510697 64,FT: 0.539571 64: 0.517956
# Train Epoch: 32 [30000/50000 (60%)]	Losses 64,TT: 0.511732 64,TF: 0.496360 64,FT: 0.523255 64: 0.503873
# Train Epoch: 32 [40000/50000 (80%)]	Losses 64,TT: 0.488908 64,TF: 0.470787 64,FT: 0.496812 64: 0.476438
# Train Epoch: 32 [50000/50000 (100%)]	Losses 64,TT: 0.505726 64,TF: 0.489815 64,FT: 0.518319 64: 0.495552
# Test set:
# 64,TT: loss: 0.4695	rho_loss: 0.0001
# 64,TF: loss: 0.4597	rho_loss: 0.0001
# 64,FT: loss: 0.4775	rho_loss: 0.0001
# 64: loss: 0.4660	rho_loss: 0.0001
#
# Train Epoch: 33 [0/50000 (0%)]	Losses 64,TT: 0.539149 64,TF: 0.520760 64,FT: 0.545061 64: 0.526552
# Train Epoch: 33 [10000/50000 (20%)]	Losses 64,TT: 0.526168 64,TF: 0.508607 64,FT: 0.535967 64: 0.516413
# Train Epoch: 33 [20000/50000 (40%)]	Losses 64,TT: 0.480937 64,TF: 0.466475 64,FT: 0.490364 64: 0.472821
# Train Epoch: 33 [30000/50000 (60%)]	Losses 64,TT: 0.479466 64,TF: 0.465055 64,FT: 0.490283 64: 0.470264
# Train Epoch: 33 [40000/50000 (80%)]	Losses 64,TT: 0.494660 64,TF: 0.477006 64,FT: 0.501707 64: 0.484360
# Train Epoch: 33 [50000/50000 (100%)]	Losses 64,TT: 0.508480 64,TF: 0.490066 64,FT: 0.516954 64: 0.497577
# Test set:
# 64,TT: loss: 0.4692	rho_loss: 0.0001
# 64,TF: loss: 0.4595	rho_loss: 0.0001
# 64,FT: loss: 0.4770	rho_loss: 0.0001
# 64: loss: 0.4658	rho_loss: 0.0001
#
# Train Epoch: 34 [0/50000 (0%)]	Losses 64,TT: 0.457422 64,TF: 0.444033 64,FT: 0.468898 64: 0.450355
# Train Epoch: 34 [10000/50000 (20%)]	Losses 64,TT: 0.505894 64,TF: 0.489748 64,FT: 0.515319 64: 0.496894
# Train Epoch: 34 [20000/50000 (40%)]	Losses 64,TT: 0.486752 64,TF: 0.468990 64,FT: 0.499627 64: 0.474868
# Train Epoch: 34 [30000/50000 (60%)]	Losses 64,TT: 0.481659 64,TF: 0.466725 64,FT: 0.492090 64: 0.472395
# Train Epoch: 34 [40000/50000 (80%)]	Losses 64,TT: 0.380821 64,TF: 0.363926 64,FT: 0.386651 64: 0.368210
# Train Epoch: 34 [50000/50000 (100%)]	Losses 64,TT: 0.517364 64,TF: 0.502877 64,FT: 0.525354 64: 0.508667
# Test set:
# 64,TT: loss: 0.4690	rho_loss: 0.0001
# 64,TF: loss: 0.4593	rho_loss: 0.0001
# 64,FT: loss: 0.4770	rho_loss: 0.0001
# 64: loss: 0.4652	rho_loss: 0.0001
#
# Train Epoch: 35 [0/50000 (0%)]	Losses 64,TT: 0.367751 64,TF: 0.353037 64,FT: 0.378622 64: 0.358437
# Train Epoch: 35 [10000/50000 (20%)]	Losses 64,TT: 0.437893 64,TF: 0.421983 64,FT: 0.448097 64: 0.429707
# Train Epoch: 35 [20000/50000 (40%)]	Losses 64,TT: 0.461128 64,TF: 0.445197 64,FT: 0.472777 64: 0.452590
# Train Epoch: 35 [30000/50000 (60%)]	Losses 64,TT: 0.528409 64,TF: 0.510224 64,FT: 0.533930 64: 0.517120
# Train Epoch: 35 [40000/50000 (80%)]	Losses 64,TT: 0.434095 64,TF: 0.416396 64,FT: 0.443489 64: 0.422981
# Train Epoch: 35 [50000/50000 (100%)]	Losses 64,TT: 0.437494 64,TF: 0.421407 64,FT: 0.445100 64: 0.427641
# Test set:
# 64,TT: loss: 0.4688	rho_loss: 0.0001
# 64,TF: loss: 0.4591	rho_loss: 0.0001
# 64,FT: loss: 0.4763	rho_loss: 0.0001
# 64: loss: 0.4651	rho_loss: 0.0001
#
# Train Epoch: 36 [0/50000 (0%)]	Losses 64,TT: 0.436713 64,TF: 0.421761 64,FT: 0.442860 64: 0.426762
# Train Epoch: 36 [10000/50000 (20%)]	Losses 64,TT: 0.416562 64,TF: 0.398677 64,FT: 0.423123 64: 0.404156
# Train Epoch: 36 [20000/50000 (40%)]	Losses 64,TT: 0.524739 64,TF: 0.506329 64,FT: 0.532496 64: 0.512737
# Train Epoch: 36 [30000/50000 (60%)]	Losses 64,TT: 0.514517 64,TF: 0.498048 64,FT: 0.523168 64: 0.502991
# Train Epoch: 36 [40000/50000 (80%)]	Losses 64,TT: 0.465704 64,TF: 0.450739 64,FT: 0.477527 64: 0.457063
# Train Epoch: 36 [50000/50000 (100%)]	Losses 64,TT: 0.503362 64,TF: 0.486906 64,FT: 0.514023 64: 0.492774
# Test set:
# 64,TT: loss: 0.4684	rho_loss: 0.0001
# 64,TF: loss: 0.4589	rho_loss: 0.0001
# 64,FT: loss: 0.4760	rho_loss: 0.0001
# 64: loss: 0.4645	rho_loss: 0.0001
#
# Train Epoch: 37 [0/50000 (0%)]	Losses 64,TT: 0.509052 64,TF: 0.495847 64,FT: 0.518811 64: 0.500685
# Train Epoch: 37 [10000/50000 (20%)]	Losses 64,TT: 0.563291 64,TF: 0.549271 64,FT: 0.570615 64: 0.553893
# Train Epoch: 37 [20000/50000 (40%)]	Losses 64,TT: 0.478446 64,TF: 0.460966 64,FT: 0.489652 64: 0.465942
# Train Epoch: 37 [30000/50000 (60%)]	Losses 64,TT: 0.508360 64,TF: 0.492738 64,FT: 0.519704 64: 0.497618
# Train Epoch: 37 [40000/50000 (80%)]	Losses 64,TT: 0.466403 64,TF: 0.448288 64,FT: 0.477551 64: 0.455080
# Train Epoch: 37 [50000/50000 (100%)]	Losses 64,TT: 0.444641 64,TF: 0.425310 64,FT: 0.458350 64: 0.432581
# Test set:
# 64,TT: loss: 0.4682	rho_loss: 0.0001
# 64,TF: loss: 0.4587	rho_loss: 0.0001
# 64,FT: loss: 0.4758	rho_loss: 0.0001
# 64: loss: 0.4644	rho_loss: 0.0001
#
# Train Epoch: 38 [0/50000 (0%)]	Losses 64,TT: 0.517283 64,TF: 0.501385 64,FT: 0.522641 64: 0.506897
# Train Epoch: 38 [10000/50000 (20%)]	Losses 64,TT: 0.600480 64,TF: 0.585241 64,FT: 0.608512 64: 0.590929
# Train Epoch: 38 [20000/50000 (40%)]	Losses 64,TT: 0.524303 64,TF: 0.509237 64,FT: 0.533163 64: 0.513402
# Train Epoch: 38 [30000/50000 (60%)]	Losses 64,TT: 0.503268 64,TF: 0.486620 64,FT: 0.513126 64: 0.494119
# Train Epoch: 38 [40000/50000 (80%)]	Losses 64,TT: 0.450253 64,TF: 0.435125 64,FT: 0.456219 64: 0.439275
# Train Epoch: 38 [50000/50000 (100%)]	Losses 64,TT: 0.459039 64,TF: 0.446014 64,FT: 0.466913 64: 0.450644
# Test set:
# 64,TT: loss: 0.4678	rho_loss: 0.0001
# 64,TF: loss: 0.4584	rho_loss: 0.0001
# 64,FT: loss: 0.4752	rho_loss: 0.0001
# 64: loss: 0.4640	rho_loss: 0.0001
#
# Train Epoch: 39 [0/50000 (0%)]	Losses 64,TT: 0.479080 64,TF: 0.463126 64,FT: 0.486174 64: 0.468119
# Train Epoch: 39 [10000/50000 (20%)]	Losses 64,TT: 0.493896 64,TF: 0.475155 64,FT: 0.506188 64: 0.483042
# Train Epoch: 39 [20000/50000 (40%)]	Losses 64,TT: 0.498096 64,TF: 0.482589 64,FT: 0.507675 64: 0.488601
# Train Epoch: 39 [30000/50000 (60%)]	Losses 64,TT: 0.460925 64,TF: 0.446461 64,FT: 0.469910 64: 0.451246
# Train Epoch: 39 [40000/50000 (80%)]	Losses 64,TT: 0.443006 64,TF: 0.429737 64,FT: 0.452598 64: 0.434008
# Train Epoch: 39 [50000/50000 (100%)]	Losses 64,TT: 0.560746 64,TF: 0.543911 64,FT: 0.570293 64: 0.548907
# Test set:
# 64,TT: loss: 0.4676	rho_loss: 0.0001
# 64,TF: loss: 0.4582	rho_loss: 0.0001
# 64,FT: loss: 0.4752	rho_loss: 0.0001
# 64: loss: 0.4635	rho_loss: 0.0001
#
# Train Epoch: 40 [0/50000 (0%)]	Losses 64,TT: 0.612018 64,TF: 0.595039 64,FT: 0.621670 64: 0.601040
# Train Epoch: 40 [10000/50000 (20%)]	Losses 64,TT: 0.461462 64,TF: 0.446231 64,FT: 0.478152 64: 0.452358
# Train Epoch: 40 [20000/50000 (40%)]	Losses 64,TT: 0.417304 64,TF: 0.401140 64,FT: 0.422431 64: 0.407159
# Train Epoch: 40 [30000/50000 (60%)]	Losses 64,TT: 0.512944 64,TF: 0.496104 64,FT: 0.521164 64: 0.501450
# Train Epoch: 40 [40000/50000 (80%)]	Losses 64,TT: 0.410254 64,TF: 0.396520 64,FT: 0.418508 64: 0.401129
# Train Epoch: 40 [50000/50000 (100%)]	Losses 64,TT: 0.444167 64,TF: 0.409959 64,FT: 0.434572 64: 0.413784
# Test set:
# 64,TT: loss: 0.4674	rho_loss: 0.0001
# 64,TF: loss: 0.4583	rho_loss: 0.0001
# 64,FT: loss: 0.4747	rho_loss: 0.0001
# 64: loss: 0.4634	rho_loss: 0.0001

# %%
torch.save(models['64,TF'].state_dict(), "./conv_autoencoder_fmn_mse.pth")

# %%
model = Net(64, True, False)
model.load_state_dict(torch.load('./conv_autoencoder_fmn_mse.pth'))
model.eval()
# Out:
# Net(
#   (ae): autoencoder(
#     (encoder): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc1): FullyConnected(
#       (model): Sequential(
#         (0): Linear(in_features=1568, out_features=64, bias=True)
#       )
#     )
#     (fc2): FullyConnected(
#       (model): Sequential(
#         (0): Linear(in_features=64, out_features=1568, bias=True)
#       )
#     )
#     (decoder): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2))
#       (2): Tanh()
#     )
#   )
# )

# %%
data, _ = next(iter(test_loader))
output = model(data + 0.5*torch.randn(data.size()).clamp(0,1))
output2 = model(data)
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()
to_plot2 = output2.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()

#decoded = models['plain'].decode(torch.eye(10))
#dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
#with torch.no_grad():
 #   encoded = models['plain'].E(data.view(-1, 28*28))
  #  print((encoded > 0.2).sum(1))
   # encoded[encoded < 0.2] = 0.
   # decoded_f = models['plain'].decode(encoded)
   # f_to_plot = ((decoded_f.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()

# %%
plot_mnist((data + torch.randn(data.size()).clamp(0,1)).data.numpy(), (5, 10))
plot_mnist(to_plot2, (5, 10))
plot_mnist(to_plot, (5, 10))
#plot_mnist(f_to_plot, (5, 10))
#plot_mnist(dec_to_plot, (8, 8))
