# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils import mnist, plot_graphs, plot_mnist
import numpy as np

# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
train_loader, valid_loader, test_loader = mnist(valid=10000)

# %%
class FullyConnected(nn.Module):
    def __init__(self, sizes, dropout=False, activation_fn=nn.Sigmoid()):
        super(FullyConnected, self).__init__()
        layers = []
        
        for i in range(len(sizes) - 2):
            layers.append(nn.Linear(sizes[i], sizes[i+1]))
            layers.append(activation_fn())
            if dropout:
                layers.append(nn.Dropout())

        else: # нам не нужен дропаут и фнкция активации в последнем слое
            layers.append(nn.Linear(sizes[-2], sizes[-1]))
            
        self.model = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.model(x)

# %%
class autoencoder(nn.Module):
    def __init__(self, batchnorm = False, dropout = False, latent_size = 10):
        super(autoencoder, self).__init__()
        layers = []
        layers.append(nn.Conv2d(1, 16, 3, stride=1, padding=1))
        layers.append(nn.ReLU())
        if batchnorm:
            layers.append(nn.BatchNorm2d(16))
        layers.append(nn.MaxPool2d(2, stride=2))                        
        if dropout:
            layers.append(nn.Dropout2d())
        layers.append(nn.Conv2d(16, 32, 3, stride=1, padding=1))
        layers.append(nn.ReLU())
        if batchnorm:
            layers.append(nn.BatchNorm2d(32))
        layers.append(nn.MaxPool2d(2, stride=2, return_indices=False))                        
        if dropout:
            layers.append(nn.Dropout2d())                       
        
        self.encoder = nn.Sequential(*layers)
        
        
        self.fc1 = FullyConnected([32*7*7, latent_size], dropout=True)
        self.fc2 = FullyConnected([latent_size, 32*7*7], dropout=True, activation_fn=nn.ReLU())
      
        
        layersd = []
        layersd.append(nn.ConvTranspose2d(32, 16, 3, stride=2, padding=1)) #32 14 14
        layersd.append(nn.ConvTranspose2d(16, 1, 4, stride=2, padding=0))
        layersd.append(nn.Tanh())
        
        self.decoder = nn.Sequential(*layersd)                        
        

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(-1, 32*7*7)
        x = self.fc1(x)
        x = torch.sigmoid(x)
        data_rho = x.mean(0)
        x = self.fc2(x)
        x = torch.relu(x)
        x = x.view(50, 32, 7, 7)
        x = self.decoder(x)
        return x, data_rho

# %%
class Net(nn.Module):
    def __init__(self, latent_size = 10, batchnorm = False, dropout = False,  loss_fn = 
                 F.mse_loss, lr = 1e-4, l2 = 0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.batchnorm = batchnorm
        self.dropout = dropout
        self.ae = autoencoder(batchnorm, dropout, latent_size)
        self.loss_fn = loss_fn
        self._rho_loss = None
        self._loss = None
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
    
 
    def forward(self, x):
        x, self.data_rho = self.ae(x)
        return x

    def rho_loss(self, rho, size_average=True):
        """
        D_KL(P||Q) = sum(p*log(p/q)) = -sum(p*log(q/p)) = -p*log(q/p) - (1-p)log((1-q)/(1-p))
        """
       # dkl = - torch.log(self.data_rho/rho) * rho - torch.log((1-self.data_rho)/(1-rho)) * (1-rho)
        dkl = min(- torch.log(self.data_rho) * rho - torch.log(1-self.data_rho) * (1-rho))
        if size_average:
            self._rho_loss = dkl.mean()
        else:
            self._rho_loss = dkl.sum()
        return self._rho_loss
    
    def loss(self, x, target, **kwargs):
        target = target.view(-1, 28*28)
        x = x.view(-1, 28*28)
        self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
models = {'64,TT': Net(64, True, True), '64,TF': Net(64, True, False), '64,FT': Net(64, False, True), '64': Net(64)}
rho = 0.05
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
def train(epoch, models, log=None):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, _) in enumerate(train_loader):
        dataX = (data + 0.5*torch.randn(data.size())).clamp(0,1)
        for model in models.values():
            model.optim.zero_grad()
            output = model(dataX)
            rho_loss = model.rho_loss(rho)
            loss = model.loss(output, data) + rho_loss
            loss.backward()
            model.optim.step()
            
        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._rho_loss))
        print(line + losses)

# %%
avg_lambda = lambda l: 'loss: {:.4f}'.format(l)
rho_lambda = lambda p: 'rho_loss: {:.4f}'.format(p)
line = lambda i, l, p: '{}: '.format(i) + avg_lambda(l) + '\t' + rho_lambda(p)
    
def test(models, loader, log=None):
    test_size = len(loader.sampler)


    test_loss = {k: 0. for k in models}
    rho_loss = {k: 0. for k in models}
    with torch.no_grad():
        for data, _ in loader:
            dataX = (data + 0.5*torch.randn(data.size())).clamp(0,1)
            output = {k: m(dataX) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], data, reduction='sum').item() # sum up batch loss
                rho_loss[k] += m.rho_loss(rho, size_average=False).item()
    
    for k in models:
        test_loss[k] /= (test_size * 784)
        rho_loss[k] /= (test_size * models[k].latent_size)
        if log is not None:
            log[k].append((test_loss[k], rho_loss[k]))
    
    lines = '\n'.join([line(k, test_loss[k], rho_loss[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines        
    print(report)

# %%
for epoch in range(1, 41):
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, valid_loader, test_log)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Losses 64,TT: 1.011524 64,TF: 1.017523 64,FT: 0.999010 64: 0.988210
# Train Epoch: 1 [10000/50000 (20%)]	Losses 64,TT: 0.662369 64,TF: 0.663468 64,FT: 0.670587 64: 0.674342
# Train Epoch: 1 [20000/50000 (40%)]	Losses 64,TT: 0.716522 64,TF: 0.688813 64,FT: 0.753200 64: 0.745613
# Train Epoch: 1 [30000/50000 (60%)]	Losses 64,TT: 0.631686 64,TF: 0.598945 64,FT: 0.723178 64: 0.646814
# Train Epoch: 1 [40000/50000 (80%)]	Losses 64,TT: 0.548064 64,TF: 0.510083 64,FT: 0.666920 64: 0.552471
# Train Epoch: 1 [50000/50000 (100%)]	Losses 64,TT: 0.543654 64,TF: 0.500662 64,FT: 0.620502 64: 0.539923
# Test set:
# 64,TT: loss: 0.5330	rho_loss: 0.0001
# 64,TF: loss: 0.5038	rho_loss: 0.0001
# 64,FT: loss: 0.6144	rho_loss: 0.0001
# 64: loss: 0.5426	rho_loss: 0.0001
#
# Train Epoch: 2 [0/50000 (0%)]	Losses 64,TT: 0.538139 64,TF: 0.500305 64,FT: 0.610402 64: 0.539123
# Train Epoch: 2 [10000/50000 (20%)]	Losses 64,TT: 0.534086 64,TF: 0.497252 64,FT: 0.590465 64: 0.529071
# Train Epoch: 2 [20000/50000 (40%)]	Losses 64,TT: 0.531866 64,TF: 0.489991 64,FT: 0.581938 64: 0.522924
# Train Epoch: 2 [30000/50000 (60%)]	Losses 64,TT: 0.539362 64,TF: 0.497768 64,FT: 0.585519 64: 0.528454
# Train Epoch: 2 [40000/50000 (80%)]	Losses 64,TT: 0.469822 64,TF: 0.437746 64,FT: 0.511663 64: 0.463750
# Train Epoch: 2 [50000/50000 (100%)]	Losses 64,TT: 0.460962 64,TF: 0.430652 64,FT: 0.492072 64: 0.450723
# Test set:
# 64,TT: loss: 0.4639	rho_loss: 0.0001
# 64,TF: loss: 0.4427	rho_loss: 0.0001
# 64,FT: loss: 0.5048	rho_loss: 0.0001
# 64: loss: 0.4655	rho_loss: 0.0001
#
# Train Epoch: 3 [0/50000 (0%)]	Losses 64,TT: 0.469418 64,TF: 0.442603 64,FT: 0.503614 64: 0.464662
# Train Epoch: 3 [10000/50000 (20%)]	Losses 64,TT: 0.429051 64,TF: 0.405753 64,FT: 0.458801 64: 0.423902
# Train Epoch: 3 [20000/50000 (40%)]	Losses 64,TT: 0.435061 64,TF: 0.409752 64,FT: 0.464357 64: 0.424730
# Train Epoch: 3 [30000/50000 (60%)]	Losses 64,TT: 0.436997 64,TF: 0.411830 64,FT: 0.467594 64: 0.431119
# Train Epoch: 3 [40000/50000 (80%)]	Losses 64,TT: 0.402484 64,TF: 0.380866 64,FT: 0.428413 64: 0.396398
# Train Epoch: 3 [50000/50000 (100%)]	Losses 64,TT: 0.444390 64,TF: 0.415253 64,FT: 0.463650 64: 0.431113
# Test set:
# 64,TT: loss: 0.4400	rho_loss: 0.0001
# 64,TF: loss: 0.4223	rho_loss: 0.0001
# 64,FT: loss: 0.4688	rho_loss: 0.0001
# 64: loss: 0.4386	rho_loss: 0.0001
#
# Train Epoch: 4 [0/50000 (0%)]	Losses 64,TT: 0.460781 64,TF: 0.432887 64,FT: 0.490434 64: 0.451098
# Train Epoch: 4 [10000/50000 (20%)]	Losses 64,TT: 0.435016 64,TF: 0.408329 64,FT: 0.458714 64: 0.422900
# Train Epoch: 4 [20000/50000 (40%)]	Losses 64,TT: 0.446993 64,TF: 0.423698 64,FT: 0.475159 64: 0.439299
# Train Epoch: 4 [30000/50000 (60%)]	Losses 64,TT: 0.427855 64,TF: 0.406100 64,FT: 0.449033 64: 0.418929
# Train Epoch: 4 [40000/50000 (80%)]	Losses 64,TT: 0.451784 64,TF: 0.426558 64,FT: 0.470680 64: 0.439095
# Train Epoch: 4 [50000/50000 (100%)]	Losses 64,TT: 0.463516 64,TF: 0.437764 64,FT: 0.490112 64: 0.451571
# Test set:
# 64,TT: loss: 0.4266	rho_loss: 0.0001
# 64,TF: loss: 0.4103	rho_loss: 0.0001
# 64,FT: loss: 0.4511	rho_loss: 0.0001
# 64: loss: 0.4243	rho_loss: 0.0001
#
# Train Epoch: 5 [0/50000 (0%)]	Losses 64,TT: 0.430220 64,TF: 0.406948 64,FT: 0.454662 64: 0.421723
# Train Epoch: 5 [10000/50000 (20%)]	Losses 64,TT: 0.426846 64,TF: 0.402005 64,FT: 0.444104 64: 0.414257
# Train Epoch: 5 [20000/50000 (40%)]	Losses 64,TT: 0.441930 64,TF: 0.416698 64,FT: 0.464043 64: 0.430313
# Train Epoch: 5 [30000/50000 (60%)]	Losses 64,TT: 0.422272 64,TF: 0.401399 64,FT: 0.441647 64: 0.411261
# Train Epoch: 5 [40000/50000 (80%)]	Losses 64,TT: 0.430899 64,TF: 0.402606 64,FT: 0.448478 64: 0.417092
# Train Epoch: 5 [50000/50000 (100%)]	Losses 64,TT: 0.424722 64,TF: 0.403142 64,FT: 0.448629 64: 0.414867
# Test set:
# 64,TT: loss: 0.4175	rho_loss: 0.0001
# 64,TF: loss: 0.4030	rho_loss: 0.0001
# 64,FT: loss: 0.4400	rho_loss: 0.0001
# 64: loss: 0.4136	rho_loss: 0.0001
#
# Train Epoch: 6 [0/50000 (0%)]	Losses 64,TT: 0.431687 64,TF: 0.403827 64,FT: 0.450177 64: 0.417007
# Train Epoch: 6 [10000/50000 (20%)]	Losses 64,TT: 0.453151 64,TF: 0.428250 64,FT: 0.472478 64: 0.440180
# Train Epoch: 6 [20000/50000 (40%)]	Losses 64,TT: 0.424545 64,TF: 0.402692 64,FT: 0.445773 64: 0.411478
# Train Epoch: 6 [30000/50000 (60%)]	Losses 64,TT: 0.439322 64,TF: 0.420362 64,FT: 0.462330 64: 0.428611
# Train Epoch: 6 [40000/50000 (80%)]	Losses 64,TT: 0.439674 64,TF: 0.417793 64,FT: 0.458114 64: 0.426179
# Train Epoch: 6 [50000/50000 (100%)]	Losses 64,TT: 0.442599 64,TF: 0.419596 64,FT: 0.461060 64: 0.427115
# Test set:
# 64,TT: loss: 0.4106	rho_loss: 0.0001
# 64,TF: loss: 0.3976	rho_loss: 0.0001
# 64,FT: loss: 0.4318	rho_loss: 0.0001
# 64: loss: 0.4057	rho_loss: 0.0001
#
# Train Epoch: 7 [0/50000 (0%)]	Losses 64,TT: 0.420969 64,TF: 0.399760 64,FT: 0.445334 64: 0.408742
# Train Epoch: 7 [10000/50000 (20%)]	Losses 64,TT: 0.416853 64,TF: 0.396357 64,FT: 0.439107 64: 0.405456
# Train Epoch: 7 [20000/50000 (40%)]	Losses 64,TT: 0.402413 64,TF: 0.381791 64,FT: 0.426525 64: 0.389066
# Train Epoch: 7 [30000/50000 (60%)]	Losses 64,TT: 0.433202 64,TF: 0.414056 64,FT: 0.453551 64: 0.419394
# Train Epoch: 7 [40000/50000 (80%)]	Losses 64,TT: 0.421870 64,TF: 0.400645 64,FT: 0.439732 64: 0.406650
# Train Epoch: 7 [50000/50000 (100%)]	Losses 64,TT: 0.452713 64,TF: 0.430715 64,FT: 0.472883 64: 0.437729
# Test set:
# 64,TT: loss: 0.4047	rho_loss: 0.0001
# 64,TF: loss: 0.3941	rho_loss: 0.0001
# 64,FT: loss: 0.4256	rho_loss: 0.0001
# 64: loss: 0.3998	rho_loss: 0.0001
#
# Train Epoch: 8 [0/50000 (0%)]	Losses 64,TT: 0.407504 64,TF: 0.385292 64,FT: 0.423853 64: 0.391264
# Train Epoch: 8 [10000/50000 (20%)]	Losses 64,TT: 0.426236 64,TF: 0.401051 64,FT: 0.440092 64: 0.406976
# Train Epoch: 8 [20000/50000 (40%)]	Losses 64,TT: 0.432287 64,TF: 0.415307 64,FT: 0.458499 64: 0.420636
# Train Epoch: 8 [30000/50000 (60%)]	Losses 64,TT: 0.416430 64,TF: 0.397993 64,FT: 0.434494 64: 0.403709
# Train Epoch: 8 [40000/50000 (80%)]	Losses 64,TT: 0.417642 64,TF: 0.400042 64,FT: 0.432675 64: 0.404654
# Train Epoch: 8 [50000/50000 (100%)]	Losses 64,TT: 0.417519 64,TF: 0.398143 64,FT: 0.435399 64: 0.402734
# Test set:
# 64,TT: loss: 0.3999	rho_loss: 0.0001
# 64,TF: loss: 0.3908	rho_loss: 0.0001
# 64,FT: loss: 0.4194	rho_loss: 0.0001
# 64: loss: 0.3952	rho_loss: 0.0001
#
# Train Epoch: 9 [0/50000 (0%)]	Losses 64,TT: 0.422452 64,TF: 0.407309 64,FT: 0.441384 64: 0.411694
# Train Epoch: 9 [10000/50000 (20%)]	Losses 64,TT: 0.482727 64,TF: 0.460655 64,FT: 0.499684 64: 0.465145
# Train Epoch: 9 [20000/50000 (40%)]	Losses 64,TT: 0.420585 64,TF: 0.405392 64,FT: 0.436379 64: 0.408847
# Train Epoch: 9 [30000/50000 (60%)]	Losses 64,TT: 0.379769 64,TF: 0.363805 64,FT: 0.396973 64: 0.367457
# Train Epoch: 9 [40000/50000 (80%)]	Losses 64,TT: 0.386917 64,TF: 0.370417 64,FT: 0.404545 64: 0.373148
# Train Epoch: 9 [50000/50000 (100%)]	Losses 64,TT: 0.412470 64,TF: 0.396630 64,FT: 0.435668 64: 0.400845
# Test set:
# 64,TT: loss: 0.3966	rho_loss: 0.0001
# 64,TF: loss: 0.3884	rho_loss: 0.0001
# 64,FT: loss: 0.4148	rho_loss: 0.0001
# 64: loss: 0.3918	rho_loss: 0.0001
#
# Train Epoch: 10 [0/50000 (0%)]	Losses 64,TT: 0.430306 64,TF: 0.412747 64,FT: 0.443893 64: 0.415320
# Train Epoch: 10 [10000/50000 (20%)]	Losses 64,TT: 0.425468 64,TF: 0.407578 64,FT: 0.440854 64: 0.411457
# Train Epoch: 10 [20000/50000 (40%)]	Losses 64,TT: 0.392319 64,TF: 0.376450 64,FT: 0.408104 64: 0.379701
# Train Epoch: 10 [30000/50000 (60%)]	Losses 64,TT: 0.386182 64,TF: 0.368533 64,FT: 0.403745 64: 0.371798
# Train Epoch: 10 [40000/50000 (80%)]	Losses 64,TT: 0.407632 64,TF: 0.392549 64,FT: 0.427675 64: 0.395338
# Train Epoch: 10 [50000/50000 (100%)]	Losses 64,TT: 0.380546 64,TF: 0.364192 64,FT: 0.398510 64: 0.367120
# Test set:
# 64,TT: loss: 0.3933	rho_loss: 0.0001
# 64,TF: loss: 0.3862	rho_loss: 0.0001
# 64,FT: loss: 0.4108	rho_loss: 0.0001
# 64: loss: 0.3889	rho_loss: 0.0001
#
# Train Epoch: 11 [0/50000 (0%)]	Losses 64,TT: 0.380639 64,TF: 0.365526 64,FT: 0.396328 64: 0.367246
# Train Epoch: 11 [10000/50000 (20%)]	Losses 64,TT: 0.411673 64,TF: 0.395971 64,FT: 0.428748 64: 0.398843
# Train Epoch: 11 [20000/50000 (40%)]	Losses 64,TT: 0.422952 64,TF: 0.407349 64,FT: 0.441736 64: 0.409439
# Train Epoch: 11 [30000/50000 (60%)]	Losses 64,TT: 0.392813 64,TF: 0.375447 64,FT: 0.410675 64: 0.378722
# Train Epoch: 11 [40000/50000 (80%)]	Losses 64,TT: 0.383757 64,TF: 0.369075 64,FT: 0.396028 64: 0.371984
# Train Epoch: 11 [50000/50000 (100%)]	Losses 64,TT: 0.411255 64,TF: 0.394948 64,FT: 0.429142 64: 0.397657
# Test set:
# 64,TT: loss: 0.3907	rho_loss: 0.0001
# 64,TF: loss: 0.3843	rho_loss: 0.0001
# 64,FT: loss: 0.4072	rho_loss: 0.0001
# 64: loss: 0.3863	rho_loss: 0.0001
#
# Train Epoch: 12 [0/50000 (0%)]	Losses 64,TT: 0.414047 64,TF: 0.397391 64,FT: 0.428897 64: 0.399887
# Train Epoch: 12 [10000/50000 (20%)]	Losses 64,TT: 0.377463 64,TF: 0.360324 64,FT: 0.390544 64: 0.363386
# Train Epoch: 12 [20000/50000 (40%)]	Losses 64,TT: 0.353279 64,TF: 0.339751 64,FT: 0.366698 64: 0.340893
# Train Epoch: 12 [30000/50000 (60%)]	Losses 64,TT: 0.402111 64,TF: 0.387665 64,FT: 0.416802 64: 0.388272
# Train Epoch: 12 [40000/50000 (80%)]	Losses 64,TT: 0.370851 64,TF: 0.355185 64,FT: 0.383575 64: 0.356555
# Train Epoch: 12 [50000/50000 (100%)]	Losses 64,TT: 0.412843 64,TF: 0.398462 64,FT: 0.428811 64: 0.399859
# Test set:
# 64,TT: loss: 0.3886	rho_loss: 0.0001
# 64,TF: loss: 0.3825	rho_loss: 0.0001
# 64,FT: loss: 0.4040	rho_loss: 0.0001
# 64: loss: 0.3843	rho_loss: 0.0001
#
# Train Epoch: 13 [0/50000 (0%)]	Losses 64,TT: 0.393360 64,TF: 0.381427 64,FT: 0.410311 64: 0.382674
# Train Epoch: 13 [10000/50000 (20%)]	Losses 64,TT: 0.403811 64,TF: 0.388076 64,FT: 0.419155 64: 0.388407
# Train Epoch: 13 [20000/50000 (40%)]	Losses 64,TT: 0.402049 64,TF: 0.387866 64,FT: 0.416591 64: 0.388720
# Train Epoch: 13 [30000/50000 (60%)]	Losses 64,TT: 0.381086 64,TF: 0.369457 64,FT: 0.397335 64: 0.370585
# Train Epoch: 13 [40000/50000 (80%)]	Losses 64,TT: 0.391050 64,TF: 0.379204 64,FT: 0.408428 64: 0.378561
# Train Epoch: 13 [50000/50000 (100%)]	Losses 64,TT: 0.352596 64,TF: 0.338028 64,FT: 0.366893 64: 0.337533
# Test set:
# 64,TT: loss: 0.3866	rho_loss: 0.0001
# 64,TF: loss: 0.3812	rho_loss: 0.0001
# 64,FT: loss: 0.4014	rho_loss: 0.0001
# 64: loss: 0.3822	rho_loss: 0.0001
#
# Train Epoch: 14 [0/50000 (0%)]	Losses 64,TT: 0.426490 64,TF: 0.414432 64,FT: 0.442268 64: 0.414974
# Train Epoch: 14 [10000/50000 (20%)]	Losses 64,TT: 0.374413 64,TF: 0.361053 64,FT: 0.385753 64: 0.361690
# Train Epoch: 14 [20000/50000 (40%)]	Losses 64,TT: 0.382728 64,TF: 0.367659 64,FT: 0.394626 64: 0.368576
# Train Epoch: 14 [30000/50000 (60%)]	Losses 64,TT: 0.437898 64,TF: 0.423173 64,FT: 0.452880 64: 0.424999
# Train Epoch: 14 [40000/50000 (80%)]	Losses 64,TT: 0.421857 64,TF: 0.409280 64,FT: 0.434511 64: 0.409304
# Train Epoch: 14 [50000/50000 (100%)]	Losses 64,TT: 0.363692 64,TF: 0.350507 64,FT: 0.378550 64: 0.351527
# Test set:
# 64,TT: loss: 0.3851	rho_loss: 0.0001
# 64,TF: loss: 0.3800	rho_loss: 0.0001
# 64,FT: loss: 0.3985	rho_loss: 0.0001
# 64: loss: 0.3805	rho_loss: 0.0001
#
# Train Epoch: 15 [0/50000 (0%)]	Losses 64,TT: 0.397369 64,TF: 0.383490 64,FT: 0.410739 64: 0.384741
# Train Epoch: 15 [10000/50000 (20%)]	Losses 64,TT: 0.390402 64,TF: 0.377238 64,FT: 0.402970 64: 0.377785
# Train Epoch: 15 [20000/50000 (40%)]	Losses 64,TT: 0.399437 64,TF: 0.386401 64,FT: 0.415447 64: 0.386618
# Train Epoch: 15 [30000/50000 (60%)]	Losses 64,TT: 0.391561 64,TF: 0.380373 64,FT: 0.406005 64: 0.380161
# Train Epoch: 15 [40000/50000 (80%)]	Losses 64,TT: 0.385105 64,TF: 0.371356 64,FT: 0.398004 64: 0.371781
# Train Epoch: 15 [50000/50000 (100%)]	Losses 64,TT: 0.414800 64,TF: 0.401595 64,FT: 0.428238 64: 0.402247
# Test set:
# 64,TT: loss: 0.3836	rho_loss: 0.0001
# 64,TF: loss: 0.3788	rho_loss: 0.0001
# 64,FT: loss: 0.3966	rho_loss: 0.0001
# 64: loss: 0.3790	rho_loss: 0.0001
#
# Train Epoch: 16 [0/50000 (0%)]	Losses 64,TT: 0.402686 64,TF: 0.390134 64,FT: 0.417096 64: 0.391831
# Train Epoch: 16 [10000/50000 (20%)]	Losses 64,TT: 0.399826 64,TF: 0.387109 64,FT: 0.412880 64: 0.385788
# Train Epoch: 16 [20000/50000 (40%)]	Losses 64,TT: 0.385319 64,TF: 0.372971 64,FT: 0.398239 64: 0.372419
# Train Epoch: 16 [30000/50000 (60%)]	Losses 64,TT: 0.402633 64,TF: 0.389761 64,FT: 0.421692 64: 0.390424
# Train Epoch: 16 [40000/50000 (80%)]	Losses 64,TT: 0.397944 64,TF: 0.383646 64,FT: 0.410242 64: 0.384283
# Train Epoch: 16 [50000/50000 (100%)]	Losses 64,TT: 0.392170 64,TF: 0.379088 64,FT: 0.405095 64: 0.379377
# Test set:
# 64,TT: loss: 0.3820	rho_loss: 0.0001
# 64,TF: loss: 0.3777	rho_loss: 0.0001
# 64,FT: loss: 0.3948	rho_loss: 0.0001
# 64: loss: 0.3777	rho_loss: 0.0001
#
# Train Epoch: 17 [0/50000 (0%)]	Losses 64,TT: 0.406538 64,TF: 0.394614 64,FT: 0.420265 64: 0.393065
# Train Epoch: 17 [10000/50000 (20%)]	Losses 64,TT: 0.385326 64,TF: 0.373293 64,FT: 0.396839 64: 0.371470
# Train Epoch: 17 [20000/50000 (40%)]	Losses 64,TT: 0.377393 64,TF: 0.362422 64,FT: 0.387614 64: 0.363556
# Train Epoch: 17 [30000/50000 (60%)]	Losses 64,TT: 0.377127 64,TF: 0.365044 64,FT: 0.390672 64: 0.365577
# Train Epoch: 17 [40000/50000 (80%)]	Losses 64,TT: 0.395497 64,TF: 0.384253 64,FT: 0.408173 64: 0.383294
# Train Epoch: 17 [50000/50000 (100%)]	Losses 64,TT: 0.383481 64,TF: 0.372241 64,FT: 0.398965 64: 0.371633
# Test set:
# 64,TT: loss: 0.3806	rho_loss: 0.0001
# 64,TF: loss: 0.3769	rho_loss: 0.0001
# 64,FT: loss: 0.3929	rho_loss: 0.0001
# 64: loss: 0.3765	rho_loss: 0.0001
#
# Train Epoch: 18 [0/50000 (0%)]	Losses 64,TT: 0.382242 64,TF: 0.369706 64,FT: 0.395724 64: 0.369860
# Train Epoch: 18 [10000/50000 (20%)]	Losses 64,TT: 0.376479 64,TF: 0.364867 64,FT: 0.389235 64: 0.363078
# Train Epoch: 18 [20000/50000 (40%)]	Losses 64,TT: 0.385160 64,TF: 0.371563 64,FT: 0.398498 64: 0.371577
# Train Epoch: 18 [30000/50000 (60%)]	Losses 64,TT: 0.404996 64,TF: 0.392613 64,FT: 0.420784 64: 0.392560
# Train Epoch: 18 [40000/50000 (80%)]	Losses 64,TT: 0.372719 64,TF: 0.361627 64,FT: 0.389471 64: 0.360458
# Train Epoch: 18 [50000/50000 (100%)]	Losses 64,TT: 0.363923 64,TF: 0.351138 64,FT: 0.375326 64: 0.350535
# Test set:
# 64,TT: loss: 0.3794	rho_loss: 0.0001
# 64,TF: loss: 0.3761	rho_loss: 0.0001
# 64,FT: loss: 0.3915	rho_loss: 0.0001
# 64: loss: 0.3754	rho_loss: 0.0001
#
# Train Epoch: 19 [0/50000 (0%)]	Losses 64,TT: 0.381084 64,TF: 0.368827 64,FT: 0.393279 64: 0.369715
# Train Epoch: 19 [10000/50000 (20%)]	Losses 64,TT: 0.415188 64,TF: 0.404610 64,FT: 0.429760 64: 0.402895
# Train Epoch: 19 [20000/50000 (40%)]	Losses 64,TT: 0.366204 64,TF: 0.354721 64,FT: 0.377429 64: 0.354280
# Train Epoch: 19 [30000/50000 (60%)]	Losses 64,TT: 0.366791 64,TF: 0.353529 64,FT: 0.376594 64: 0.352551
# Train Epoch: 19 [40000/50000 (80%)]	Losses 64,TT: 0.371580 64,TF: 0.360064 64,FT: 0.383614 64: 0.358434
# Train Epoch: 19 [50000/50000 (100%)]	Losses 64,TT: 0.367630 64,TF: 0.356648 64,FT: 0.381092 64: 0.356083
# Test set:
# 64,TT: loss: 0.3784	rho_loss: 0.0001
# 64,TF: loss: 0.3753	rho_loss: 0.0001
# 64,FT: loss: 0.3902	rho_loss: 0.0001
# 64: loss: 0.3743	rho_loss: 0.0001
#
# Train Epoch: 20 [0/50000 (0%)]	Losses 64,TT: 0.381654 64,TF: 0.371450 64,FT: 0.395739 64: 0.369056
# Train Epoch: 20 [10000/50000 (20%)]	Losses 64,TT: 0.387221 64,TF: 0.374610 64,FT: 0.400526 64: 0.372837
# Train Epoch: 20 [20000/50000 (40%)]	Losses 64,TT: 0.387534 64,TF: 0.379136 64,FT: 0.398063 64: 0.377733
# Train Epoch: 20 [30000/50000 (60%)]	Losses 64,TT: 0.384072 64,TF: 0.374285 64,FT: 0.395986 64: 0.373406
# Train Epoch: 20 [40000/50000 (80%)]	Losses 64,TT: 0.414625 64,TF: 0.400921 64,FT: 0.424866 64: 0.400251
# Train Epoch: 20 [50000/50000 (100%)]	Losses 64,TT: 0.362284 64,TF: 0.350343 64,FT: 0.373813 64: 0.349072
# Test set:
# 64,TT: loss: 0.3774	rho_loss: 0.0001
# 64,TF: loss: 0.3747	rho_loss: 0.0001
# 64,FT: loss: 0.3891	rho_loss: 0.0001
# 64: loss: 0.3737	rho_loss: 0.0001
#
# Train Epoch: 21 [0/50000 (0%)]	Losses 64,TT: 0.403417 64,TF: 0.396017 64,FT: 0.418945 64: 0.395040
# Train Epoch: 21 [10000/50000 (20%)]	Losses 64,TT: 0.393493 64,TF: 0.382429 64,FT: 0.407010 64: 0.382244
# Train Epoch: 21 [20000/50000 (40%)]	Losses 64,TT: 0.360990 64,TF: 0.349616 64,FT: 0.376509 64: 0.349122
# Train Epoch: 21 [30000/50000 (60%)]	Losses 64,TT: 0.388247 64,TF: 0.376590 64,FT: 0.399370 64: 0.374445
# Train Epoch: 21 [40000/50000 (80%)]	Losses 64,TT: 0.371976 64,TF: 0.358268 64,FT: 0.381813 64: 0.356301
# Train Epoch: 21 [50000/50000 (100%)]	Losses 64,TT: 0.433835 64,TF: 0.420221 64,FT: 0.445172 64: 0.417987
# Test set:
# 64,TT: loss: 0.3765	rho_loss: 0.0001
# 64,TF: loss: 0.3743	rho_loss: 0.0001
# 64,FT: loss: 0.3878	rho_loss: 0.0001
# 64: loss: 0.3725	rho_loss: 0.0001
#
# Train Epoch: 22 [0/50000 (0%)]	Losses 64,TT: 0.379854 64,TF: 0.371107 64,FT: 0.392996 64: 0.368718
# Train Epoch: 22 [10000/50000 (20%)]	Losses 64,TT: 0.399306 64,TF: 0.387990 64,FT: 0.409369 64: 0.386272
# Train Epoch: 22 [20000/50000 (40%)]	Losses 64,TT: 0.371499 64,TF: 0.361680 64,FT: 0.382719 64: 0.360539
# Train Epoch: 22 [30000/50000 (60%)]	Losses 64,TT: 0.395954 64,TF: 0.384948 64,FT: 0.404888 64: 0.382416
# Train Epoch: 22 [40000/50000 (80%)]	Losses 64,TT: 0.387377 64,TF: 0.375436 64,FT: 0.398475 64: 0.373208
# Train Epoch: 22 [50000/50000 (100%)]	Losses 64,TT: 0.394256 64,TF: 0.381234 64,FT: 0.404646 64: 0.379957
# Test set:
# 64,TT: loss: 0.3756	rho_loss: 0.0001
# 64,TF: loss: 0.3733	rho_loss: 0.0001
# 64,FT: loss: 0.3865	rho_loss: 0.0001
# 64: loss: 0.3716	rho_loss: 0.0001
#
# Train Epoch: 23 [0/50000 (0%)]	Losses 64,TT: 0.372811 64,TF: 0.357890 64,FT: 0.383571 64: 0.356949
# Train Epoch: 23 [10000/50000 (20%)]	Losses 64,TT: 0.380902 64,TF: 0.367538 64,FT: 0.389277 64: 0.365100
# Train Epoch: 23 [20000/50000 (40%)]	Losses 64,TT: 0.378096 64,TF: 0.367953 64,FT: 0.388596 64: 0.366144
# Train Epoch: 23 [30000/50000 (60%)]	Losses 64,TT: 0.371767 64,TF: 0.361898 64,FT: 0.382667 64: 0.360307
# Train Epoch: 23 [40000/50000 (80%)]	Losses 64,TT: 0.401425 64,TF: 0.387023 64,FT: 0.413843 64: 0.385753
# Train Epoch: 23 [50000/50000 (100%)]	Losses 64,TT: 0.373023 64,TF: 0.362362 64,FT: 0.381608 64: 0.360473
# Test set:
# 64,TT: loss: 0.3746	rho_loss: 0.0001
# 64,TF: loss: 0.3727	rho_loss: 0.0001
# 64,FT: loss: 0.3856	rho_loss: 0.0001
# 64: loss: 0.3709	rho_loss: 0.0001
#
# Train Epoch: 24 [0/50000 (0%)]	Losses 64,TT: 0.374280 64,TF: 0.360041 64,FT: 0.384688 64: 0.358244
# Train Epoch: 24 [10000/50000 (20%)]	Losses 64,TT: 0.367582 64,TF: 0.356751 64,FT: 0.375521 64: 0.354757
# Train Epoch: 24 [20000/50000 (40%)]	Losses 64,TT: 0.382849 64,TF: 0.372764 64,FT: 0.394311 64: 0.371538
# Train Epoch: 24 [30000/50000 (60%)]	Losses 64,TT: 0.400827 64,TF: 0.392961 64,FT: 0.414240 64: 0.390960
# Train Epoch: 24 [40000/50000 (80%)]	Losses 64,TT: 0.395849 64,TF: 0.383842 64,FT: 0.408628 64: 0.382468
# Train Epoch: 24 [50000/50000 (100%)]	Losses 64,TT: 0.405105 64,TF: 0.393115 64,FT: 0.415778 64: 0.390854
# Test set:
# 64,TT: loss: 0.3740	rho_loss: 0.0001
# 64,TF: loss: 0.3722	rho_loss: 0.0001
# 64,FT: loss: 0.3844	rho_loss: 0.0001
# 64: loss: 0.3702	rho_loss: 0.0001
#
# Train Epoch: 25 [0/50000 (0%)]	Losses 64,TT: 0.372053 64,TF: 0.362232 64,FT: 0.384324 64: 0.359539
# Train Epoch: 25 [10000/50000 (20%)]	Losses 64,TT: 0.386158 64,TF: 0.375086 64,FT: 0.396685 64: 0.373425
# Train Epoch: 25 [20000/50000 (40%)]	Losses 64,TT: 0.372838 64,TF: 0.364331 64,FT: 0.385514 64: 0.362345
# Train Epoch: 25 [30000/50000 (60%)]	Losses 64,TT: 0.404689 64,TF: 0.396913 64,FT: 0.415975 64: 0.394313
# Train Epoch: 25 [40000/50000 (80%)]	Losses 64,TT: 0.370205 64,TF: 0.360702 64,FT: 0.381042 64: 0.357771
# Train Epoch: 25 [50000/50000 (100%)]	Losses 64,TT: 0.362127 64,TF: 0.353320 64,FT: 0.372640 64: 0.350843
# Test set:
# 64,TT: loss: 0.3733	rho_loss: 0.0001
# 64,TF: loss: 0.3718	rho_loss: 0.0001
# 64,FT: loss: 0.3833	rho_loss: 0.0001
# 64: loss: 0.3696	rho_loss: 0.0001
#
# Train Epoch: 26 [0/50000 (0%)]	Losses 64,TT: 0.350476 64,TF: 0.339565 64,FT: 0.360033 64: 0.337067
# Train Epoch: 26 [10000/50000 (20%)]	Losses 64,TT: 0.392557 64,TF: 0.383430 64,FT: 0.402297 64: 0.380260
# Train Epoch: 26 [20000/50000 (40%)]	Losses 64,TT: 0.371597 64,TF: 0.362378 64,FT: 0.379949 64: 0.359820
# Train Epoch: 26 [30000/50000 (60%)]	Losses 64,TT: 0.378567 64,TF: 0.369911 64,FT: 0.390181 64: 0.366752
# Train Epoch: 26 [40000/50000 (80%)]	Losses 64,TT: 0.375690 64,TF: 0.368170 64,FT: 0.384773 64: 0.365859
# Train Epoch: 26 [50000/50000 (100%)]	Losses 64,TT: 0.389246 64,TF: 0.377826 64,FT: 0.402040 64: 0.375600
# Test set:
# 64,TT: loss: 0.3728	rho_loss: 0.0001
# 64,TF: loss: 0.3713	rho_loss: 0.0001
# 64,FT: loss: 0.3826	rho_loss: 0.0001
# 64: loss: 0.3689	rho_loss: 0.0001
#
# Train Epoch: 27 [0/50000 (0%)]	Losses 64,TT: 0.376633 64,TF: 0.365200 64,FT: 0.384728 64: 0.361740
# Train Epoch: 27 [10000/50000 (20%)]	Losses 64,TT: 0.405259 64,TF: 0.396326 64,FT: 0.416960 64: 0.393223
# Train Epoch: 27 [20000/50000 (40%)]	Losses 64,TT: 0.403428 64,TF: 0.393497 64,FT: 0.412471 64: 0.392229
# Train Epoch: 27 [30000/50000 (60%)]	Losses 64,TT: 0.366765 64,TF: 0.357251 64,FT: 0.377368 64: 0.353588
# Train Epoch: 27 [40000/50000 (80%)]	Losses 64,TT: 0.380471 64,TF: 0.372498 64,FT: 0.390578 64: 0.369514
# Train Epoch: 27 [50000/50000 (100%)]	Losses 64,TT: 0.360786 64,TF: 0.352959 64,FT: 0.370832 64: 0.350692
# Test set:
# 64,TT: loss: 0.3720	rho_loss: 0.0001
# 64,TF: loss: 0.3709	rho_loss: 0.0001
# 64,FT: loss: 0.3817	rho_loss: 0.0001
# 64: loss: 0.3684	rho_loss: 0.0001
#
# Train Epoch: 28 [0/50000 (0%)]	Losses 64,TT: 0.405430 64,TF: 0.396641 64,FT: 0.415133 64: 0.393764
# Train Epoch: 28 [10000/50000 (20%)]	Losses 64,TT: 0.405098 64,TF: 0.395228 64,FT: 0.414897 64: 0.391439
# Train Epoch: 28 [20000/50000 (40%)]	Losses 64,TT: 0.396217 64,TF: 0.386021 64,FT: 0.406407 64: 0.383950
# Train Epoch: 28 [30000/50000 (60%)]	Losses 64,TT: 0.341576 64,TF: 0.331124 64,FT: 0.350827 64: 0.329361
# Train Epoch: 28 [40000/50000 (80%)]	Losses 64,TT: 0.378740 64,TF: 0.368691 64,FT: 0.387726 64: 0.366743
# Train Epoch: 28 [50000/50000 (100%)]	Losses 64,TT: 0.386240 64,TF: 0.377205 64,FT: 0.396731 64: 0.374311
# Test set:
# 64,TT: loss: 0.3712	rho_loss: 0.0001
# 64,TF: loss: 0.3705	rho_loss: 0.0001
# 64,FT: loss: 0.3806	rho_loss: 0.0001
# 64: loss: 0.3677	rho_loss: 0.0001
#
# Train Epoch: 29 [0/50000 (0%)]	Losses 64,TT: 0.399807 64,TF: 0.390794 64,FT: 0.409614 64: 0.387760
# Train Epoch: 29 [10000/50000 (20%)]	Losses 64,TT: 0.375023 64,TF: 0.367677 64,FT: 0.387167 64: 0.364264
# Train Epoch: 29 [20000/50000 (40%)]	Losses 64,TT: 0.380563 64,TF: 0.373902 64,FT: 0.391993 64: 0.371193
# Train Epoch: 29 [30000/50000 (60%)]	Losses 64,TT: 0.338003 64,TF: 0.327545 64,FT: 0.346360 64: 0.325080
# Train Epoch: 29 [40000/50000 (80%)]	Losses 64,TT: 0.372884 64,TF: 0.363518 64,FT: 0.382147 64: 0.361186
# Train Epoch: 29 [50000/50000 (100%)]	Losses 64,TT: 0.366832 64,TF: 0.358463 64,FT: 0.378403 64: 0.356358
# Test set:
# 64,TT: loss: 0.3706	rho_loss: 0.0001
# 64,TF: loss: 0.3701	rho_loss: 0.0001
# 64,FT: loss: 0.3800	rho_loss: 0.0001
# 64: loss: 0.3673	rho_loss: 0.0001
#
# Train Epoch: 30 [0/50000 (0%)]	Losses 64,TT: 0.356879 64,TF: 0.344994 64,FT: 0.364596 64: 0.341669
# Train Epoch: 30 [10000/50000 (20%)]	Losses 64,TT: 0.382029 64,TF: 0.373683 64,FT: 0.389428 64: 0.371419
# Train Epoch: 30 [20000/50000 (40%)]	Losses 64,TT: 0.391118 64,TF: 0.382343 64,FT: 0.404140 64: 0.379523
# Train Epoch: 30 [30000/50000 (60%)]	Losses 64,TT: 0.398888 64,TF: 0.387843 64,FT: 0.409273 64: 0.385771
# Train Epoch: 30 [40000/50000 (80%)]	Losses 64,TT: 0.337564 64,TF: 0.328590 64,FT: 0.346852 64: 0.324675
# Train Epoch: 30 [50000/50000 (100%)]	Losses 64,TT: 0.368018 64,TF: 0.359122 64,FT: 0.374881 64: 0.355898
# Test set:
# 64,TT: loss: 0.3699	rho_loss: 0.0001
# 64,TF: loss: 0.3697	rho_loss: 0.0001
# 64,FT: loss: 0.3792	rho_loss: 0.0001
# 64: loss: 0.3667	rho_loss: 0.0001
#
# Train Epoch: 31 [0/50000 (0%)]	Losses 64,TT: 0.371271 64,TF: 0.364427 64,FT: 0.381337 64: 0.361520
# Train Epoch: 31 [10000/50000 (20%)]	Losses 64,TT: 0.362707 64,TF: 0.354299 64,FT: 0.372744 64: 0.349230
# Train Epoch: 31 [20000/50000 (40%)]	Losses 64,TT: 0.368789 64,TF: 0.359919 64,FT: 0.381222 64: 0.357948
# Train Epoch: 31 [30000/50000 (60%)]	Losses 64,TT: 0.371726 64,TF: 0.361701 64,FT: 0.379375 64: 0.359401
# Train Epoch: 31 [40000/50000 (80%)]	Losses 64,TT: 0.366590 64,TF: 0.357553 64,FT: 0.377629 64: 0.353445
# Train Epoch: 31 [50000/50000 (100%)]	Losses 64,TT: 0.348352 64,TF: 0.337549 64,FT: 0.356570 64: 0.334078
# Test set:
# 64,TT: loss: 0.3696	rho_loss: 0.0001
# 64,TF: loss: 0.3694	rho_loss: 0.0001
# 64,FT: loss: 0.3788	rho_loss: 0.0001
# 64: loss: 0.3664	rho_loss: 0.0001
#
# Train Epoch: 32 [0/50000 (0%)]	Losses 64,TT: 0.373540 64,TF: 0.365658 64,FT: 0.382508 64: 0.362378
# Train Epoch: 32 [10000/50000 (20%)]	Losses 64,TT: 0.361291 64,TF: 0.354624 64,FT: 0.369904 64: 0.351219
# Train Epoch: 32 [20000/50000 (40%)]	Losses 64,TT: 0.397395 64,TF: 0.388971 64,FT: 0.406386 64: 0.385305
# Train Epoch: 32 [30000/50000 (60%)]	Losses 64,TT: 0.378302 64,TF: 0.369141 64,FT: 0.387740 64: 0.366060
# Train Epoch: 32 [40000/50000 (80%)]	Losses 64,TT: 0.379394 64,TF: 0.372573 64,FT: 0.389988 64: 0.369895
# Train Epoch: 32 [50000/50000 (100%)]	Losses 64,TT: 0.396190 64,TF: 0.388275 64,FT: 0.405652 64: 0.384023
# Test set:
# 64,TT: loss: 0.3690	rho_loss: 0.0001
# 64,TF: loss: 0.3692	rho_loss: 0.0001
# 64,FT: loss: 0.3782	rho_loss: 0.0001
# 64: loss: 0.3658	rho_loss: 0.0001
# Train Epoch: 33 [0/50000 (0%)]	Losses 64,TT: 0.389811 64,TF: 0.381355 64,FT: 0.399134 64: 0.377932
# Train Epoch: 33 [10000/50000 (20%)]	Losses 64,TT: 0.390749 64,TF: 0.379709 64,FT: 0.396362 64: 0.376663
# Train Epoch: 33 [20000/50000 (40%)]	Losses 64,TT: 0.354526 64,TF: 0.346660 64,FT: 0.364695 64: 0.344128
# Train Epoch: 33 [30000/50000 (60%)]	Losses 64,TT: 0.421062 64,TF: 0.412870 64,FT: 0.432493 64: 0.410174
# Train Epoch: 33 [40000/50000 (80%)]	Losses 64,TT: 0.358642 64,TF: 0.349183 64,FT: 0.367884 64: 0.346120
# Train Epoch: 33 [50000/50000 (100%)]	Losses 64,TT: 0.367614 64,TF: 0.358211 64,FT: 0.372407 64: 0.354654
# Test set:
# 64,TT: loss: 0.3686	rho_loss: 0.0001
# 64,TF: loss: 0.3687	rho_loss: 0.0001
# 64,FT: loss: 0.3772	rho_loss: 0.0001
# 64: loss: 0.3653	rho_loss: 0.0001
#
# Train Epoch: 34 [0/50000 (0%)]	Losses 64,TT: 0.370370 64,TF: 0.360719 64,FT: 0.377486 64: 0.356944
# Train Epoch: 34 [10000/50000 (20%)]	Losses 64,TT: 0.374498 64,TF: 0.366715 64,FT: 0.383961 64: 0.362823
# Train Epoch: 34 [20000/50000 (40%)]	Losses 64,TT: 0.369200 64,TF: 0.356529 64,FT: 0.374025 64: 0.353241
# Train Epoch: 34 [30000/50000 (60%)]	Losses 64,TT: 0.379109 64,TF: 0.371144 64,FT: 0.387266 64: 0.369113
# Train Epoch: 34 [40000/50000 (80%)]	Losses 64,TT: 0.401119 64,TF: 0.391981 64,FT: 0.408950 64: 0.389365
# Train Epoch: 34 [50000/50000 (100%)]	Losses 64,TT: 0.425834 64,TF: 0.416581 64,FT: 0.436954 64: 0.412685
# Test set:
# 64,TT: loss: 0.3684	rho_loss: 0.0001
# 64,TF: loss: 0.3684	rho_loss: 0.0001
# 64,FT: loss: 0.3765	rho_loss: 0.0001
# 64: loss: 0.3652	rho_loss: 0.0001
#
# Train Epoch: 35 [0/50000 (0%)]	Losses 64,TT: 0.371434 64,TF: 0.364642 64,FT: 0.382025 64: 0.361203
# Train Epoch: 35 [10000/50000 (20%)]	Losses 64,TT: 0.392900 64,TF: 0.384051 64,FT: 0.401902 64: 0.380168
# Train Epoch: 35 [20000/50000 (40%)]	Losses 64,TT: 0.408875 64,TF: 0.396925 64,FT: 0.416552 64: 0.393312
# Train Epoch: 35 [30000/50000 (60%)]	Losses 64,TT: 0.369048 64,TF: 0.361597 64,FT: 0.376054 64: 0.356096
# Train Epoch: 35 [40000/50000 (80%)]	Losses 64,TT: 0.363883 64,TF: 0.354577 64,FT: 0.372261 64: 0.351195
# Train Epoch: 35 [50000/50000 (100%)]	Losses 64,TT: 0.371294 64,TF: 0.360988 64,FT: 0.378065 64: 0.358059
# Test set:
# 64,TT: loss: 0.3678	rho_loss: 0.0001
# 64,TF: loss: 0.3681	rho_loss: 0.0001
# 64,FT: loss: 0.3762	rho_loss: 0.0001
# 64: loss: 0.3646	rho_loss: 0.0001
#
# Train Epoch: 36 [0/50000 (0%)]	Losses 64,TT: 0.380757 64,TF: 0.372252 64,FT: 0.389060 64: 0.368558
# Train Epoch: 36 [10000/50000 (20%)]	Losses 64,TT: 0.364670 64,TF: 0.355464 64,FT: 0.373438 64: 0.352313
# Train Epoch: 36 [20000/50000 (40%)]	Losses 64,TT: 0.370576 64,TF: 0.363124 64,FT: 0.381328 64: 0.359321
# Train Epoch: 36 [30000/50000 (60%)]	Losses 64,TT: 0.368617 64,TF: 0.360619 64,FT: 0.376030 64: 0.356640
# Train Epoch: 36 [40000/50000 (80%)]	Losses 64,TT: 0.352857 64,TF: 0.344251 64,FT: 0.360321 64: 0.341222
# Train Epoch: 36 [50000/50000 (100%)]	Losses 64,TT: 0.350944 64,TF: 0.342508 64,FT: 0.360831 64: 0.337778
# Test set:
# 64,TT: loss: 0.3673	rho_loss: 0.0001
# 64,TF: loss: 0.3679	rho_loss: 0.0001
# 64,FT: loss: 0.3756	rho_loss: 0.0001
# 64: loss: 0.3642	rho_loss: 0.0001
#
# Train Epoch: 37 [0/50000 (0%)]	Losses 64,TT: 0.363244 64,TF: 0.351972 64,FT: 0.372435 64: 0.349070
# Train Epoch: 37 [10000/50000 (20%)]	Losses 64,TT: 0.392607 64,TF: 0.385203 64,FT: 0.404357 64: 0.380595
# Train Epoch: 37 [20000/50000 (40%)]	Losses 64,TT: 0.405078 64,TF: 0.395068 64,FT: 0.412880 64: 0.391783
# Train Epoch: 37 [30000/50000 (60%)]	Losses 64,TT: 0.376549 64,TF: 0.367950 64,FT: 0.384422 64: 0.365719
# Train Epoch: 37 [40000/50000 (80%)]	Losses 64,TT: 0.355369 64,TF: 0.346806 64,FT: 0.362333 64: 0.341959
# Train Epoch: 37 [50000/50000 (100%)]	Losses 64,TT: 0.394121 64,TF: 0.388256 64,FT: 0.402270 64: 0.385161
# Test set:
# 64,TT: loss: 0.3671	rho_loss: 0.0001
# 64,TF: loss: 0.3677	rho_loss: 0.0001
# 64,FT: loss: 0.3755	rho_loss: 0.0001
# 64: loss: 0.3638	rho_loss: 0.0001
#
# Train Epoch: 38 [0/50000 (0%)]	Losses 64,TT: 0.404029 64,TF: 0.396458 64,FT: 0.413178 64: 0.391985
# Train Epoch: 38 [10000/50000 (20%)]	Losses 64,TT: 0.397835 64,TF: 0.387544 64,FT: 0.405045 64: 0.385459
# Train Epoch: 38 [20000/50000 (40%)]	Losses 64,TT: 0.392067 64,TF: 0.385224 64,FT: 0.400696 64: 0.380651
# Train Epoch: 38 [30000/50000 (60%)]	Losses 64,TT: 0.375830 64,TF: 0.366162 64,FT: 0.388099 64: 0.362310
# Train Epoch: 38 [40000/50000 (80%)]	Losses 64,TT: 0.381094 64,TF: 0.374422 64,FT: 0.391789 64: 0.370453
# Train Epoch: 38 [50000/50000 (100%)]	Losses 64,TT: 0.356707 64,TF: 0.349145 64,FT: 0.366551 64: 0.344435
# Test set:
# 64,TT: loss: 0.3666	rho_loss: 0.0001
# 64,TF: loss: 0.3675	rho_loss: 0.0001
# 64,FT: loss: 0.3745	rho_loss: 0.0001
# 64: loss: 0.3636	rho_loss: 0.0001
#
# Train Epoch: 39 [0/50000 (0%)]	Losses 64,TT: 0.372224 64,TF: 0.364367 64,FT: 0.381405 64: 0.360623
# Train Epoch: 39 [10000/50000 (20%)]	Losses 64,TT: 0.377114 64,TF: 0.368203 64,FT: 0.384961 64: 0.364998
# Train Epoch: 39 [20000/50000 (40%)]	Losses 64,TT: 0.385117 64,TF: 0.378495 64,FT: 0.395071 64: 0.374566
# Train Epoch: 39 [30000/50000 (60%)]	Losses 64,TT: 0.382845 64,TF: 0.374658 64,FT: 0.393255 64: 0.372726
# Train Epoch: 39 [40000/50000 (80%)]	Losses 64,TT: 0.381069 64,TF: 0.371388 64,FT: 0.385312 64: 0.366605
# Train Epoch: 39 [50000/50000 (100%)]	Losses 64,TT: 0.420553 64,TF: 0.411188 64,FT: 0.427338 64: 0.405624
# Test set:
# 64,TT: loss: 0.3659	rho_loss: 0.0001
# 64,TF: loss: 0.3673	rho_loss: 0.0001
# 64,FT: loss: 0.3741	rho_loss: 0.0001
# 64: loss: 0.3632	rho_loss: 0.0001
#
# Train Epoch: 40 [0/50000 (0%)]	Losses 64,TT: 0.380540 64,TF: 0.373372 64,FT: 0.385702 64: 0.369709
# Train Epoch: 40 [10000/50000 (20%)]	Losses 64,TT: 0.380293 64,TF: 0.371929 64,FT: 0.387886 64: 0.368359
# Train Epoch: 40 [20000/50000 (40%)]	Losses 64,TT: 0.395940 64,TF: 0.389149 64,FT: 0.406247 64: 0.385064
# Train Epoch: 40 [30000/50000 (60%)]	Losses 64,TT: 0.374123 64,TF: 0.366150 64,FT: 0.380346 64: 0.362713
# Train Epoch: 40 [40000/50000 (80%)]	Losses 64,TT: 0.386722 64,TF: 0.377917 64,FT: 0.394274 64: 0.374133
# Train Epoch: 40 [50000/50000 (100%)]	Losses 64,TT: 0.384366 64,TF: 0.377771 64,FT: 0.391708 64: 0.373766
# Test set:
# 64,TT: loss: 0.3656	rho_loss: 0.0001
# 64,TF: loss: 0.3671	rho_loss: 0.0001
# 64,FT: loss: 0.3738	rho_loss: 0.0001
# 64: loss: 0.3630	rho_loss: 0.0001

# %%
torch.save(models['64'].state_dict(), './conv_autoencoder.pth')

# %%
models = Net(64)
models.load_state_dict(torch.load('./conv_autoencoder.pth'))
models.eval()
# Out:
# Net(
#   (ae): autoencoder(
#     (encoder): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc1): FullyConnected(
#       (model): Sequential(
#         (0): Linear(in_features=1568, out_features=64, bias=True)
#       )
#     )
#     (fc2): FullyConnected(
#       (model): Sequential(
#         (0): Linear(in_features=64, out_features=1568, bias=True)
#       )
#     )
#     (decoder): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2))
#       (2): Tanh()
#     )
#   )
# )

# %%
data, _ = next(iter(test_loader))
output = models['64'](data + 0.5*torch.randn(data.size()).clamp(0,1))
output2 = models['64'](data)
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()
to_plot2 = output2.view(-1, 1, 28, 28).clamp(0, 1).data.numpy()

#decoded = models['plain'].decode(torch.eye(10))
#dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
#with torch.no_grad():
 #   encoded = models['plain'].E(data.view(-1, 28*28))
  #  print((encoded > 0.2).sum(1))
   # encoded[encoded < 0.2] = 0.
   # decoded_f = models['plain'].decode(encoded)
   # f_to_plot = ((decoded_f.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()

# %%
plot_mnist((data + torch.randn(data.size()).clamp(0,1)).data.numpy(), (5, 10))
plot_mnist(to_plot2, (5, 10))
plot_mnist(to_plot, (5, 10))
#plot_mnist(f_to_plot, (5, 10))
#plot_mnist(dec_to_plot, (8, 8))
